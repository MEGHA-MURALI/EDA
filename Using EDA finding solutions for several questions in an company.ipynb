# %%
#PROBLEM 1 DATA CLEANING
#2.how many unique companies are present in companies?
import pandas as pd
import numpy as np
companies=pd.read_csv('companies.txt',sep='\t',encoding='ansi')

# %%
companies.head(2)
# Out:
#                 permalink      name            homepage_url  \
# 0     /Organization/-Fame     #fame      http://livfame.com
# 1  /Organization/-Qounter  :Qounter  http://www.qounter.com
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
#
#   state_code      region           city  founded_at
# 0         16      Mumbai         Mumbai         NaN
# 1         DE  DE - Other  Delaware City  04-09-2014

# %%
companies.shape
# Out:
# (66368, 10)

# %%
companies.columns
# Out:
# Index(['permalink', 'name', 'homepage_url', 'category_list', 'status',
#        'country_code', 'state_code', 'region', 'city', 'founded_at'],
#       dtype='object')

# %%
companies['permalink'].value_counts()
# Out:
# /Organization/Cavis-Microcaps                          1
# /Organization/Nexgenia                                 1
# /Organization/Proudigy-Inc                             1
# /Organization/Atg-Media-The-Saleroom                   1
# /Organization/Roadhop                                  1
#                                                       ..
# /Organization/Temando                                  1
# /Organization/Passbeach                                1
# /Organization/Tacit-Software                           1
# /Organization/Si2-Sistema-De-Informao-Do-Investidor    1
# /Organization/The-Better-India                         1
# Name: permalink, Length: 66368, dtype: int64

# %%
companies['companyname']=companies['permalink'].str.strip()
companies['companyname'].unique()
# Out:
# array(['/Organization/-Fame', '/Organization/-Qounter',
#        '/Organization/-The-One-Of-Them-Inc-', ...,
#        '/Organization/Ã\x81Eron', '/Organization/Ã”Asys-2',
#        '/Organization/Ä°Novatiff-Reklam-Ve-Tanä±Tä±M-Hizmetleri-Tic'],
#       dtype=object)

# %%
companies['companyname']=companies['permalink'].str.lower()
companies['companyname'].unique()
# Out:
# array(['/organization/-fame', '/organization/-qounter',
#        '/organization/-the-one-of-them-inc-', ...,
#        '/organization/ã\x81eron', '/organization/ã”asys-2',
#        '/organization/ä°novatiff-reklam-ve-tanä±tä±m-hizmetleri-tic'],
#       dtype=object)

# %%
companies['companyname'][0]
# Out:
# '/organization/-fame'

# %%
companies['companyname'][0].replace('-','')
# Out:
# '/organization/fame'

# %%
companyname=[]
for i in companies['companyname']:
    companyname.append(i.split('/')[2])
companyname
# Out:
# ['-fame',
#  '-qounter',
#  '-the-one-of-them-inc-',
#  '0-6-com',
#  '004-technologies',
#  '01games-technology',
#  '0ndine-biomedical-inc',
#  '0xdata',
#  '1',
#  '1-2-3-listo',
#  '1-4-all',
#  '1-618-technology',
#  '1-800-dentist',
#  '1-800-doctors',
#  '1-800-publicrelations-inc-',
#  '1-mainstream',
#  '1-of-99',
#  '10-20-media',
#  '10-minutes-with',
#  '1000-corks',
#  '1000-markets',
#  '1000chi',
#  '1000lookz',
#  '1000memories',
#  '1000museums-com',
#  '1001-menus',
#  '1001pharmacies-com',
#  '1006-tv',
#  '100du-tv',
#  '100e-com',
#  '100health',
#  '100plus',
#  '1010data',
#  '10alike',
#  '10bestthings',
#  '10k-2',
#  '10sec',
#  '10seconds-software',
#  '10six',
#  '10tracks-2',
#  '10x-genomics',
#  '10x-technologies',
#  '10x10-room',
#  '10â°north',
#  '11-health',
#  '115-network-disks',
#  '117go',
#  '11i-solutions',
#  '12-labs',
#  '12-star-survival',
#  '120-sports',
#  '121-rentals',
#  '121cast',
#  '121nexus',
#  '1234enter',
#  '123contactform',
#  '123feng-com',
#  '123greetings',
#  '123people',
#  '1248',
#  '128-technology',
#  '12bis',
#  '12cm',
#  '12return',
#  '12society',
#  '1366-technologies',
#  '139shop',
#  '13th-lab',
#  '140-proof',
#  '140fire',
#  '1417',
#  '15fen',
#  '15five',
#  '15minutesnow',
#  '15shopstop',
#  '16-mile-solutions',
#  '169-st',
#  '16lab-inc-',
#  '16wifi',
#  '17-media',
#  '170-systems',
#  '17hats',
#  '17u-cn',
#  '17zuoye',
#  '1800diapers',
#  '180solutions',
#  '1871',
#  '19pay',
#  '1bib',
#  '1bog',
#  '1c-company',
#  '1calendar',
#  '1cast',
#  '1click',
#  '1cloudstar-asia',
#  '1commmedical',
#  '1d4-pty',
#  '1day1song',
#  '1daylater',
#  '1daymakeover',
#  '1doc3',
#  '1docway',
#  '1energy-systems',
#  '1eq',
#  '1jiajie',
#  '1lay',
#  '1life-healthcare',
#  '1mind',
#  '1mpact-revolution-powering-helpfreely-org',
#  '1mxians',
#  '1o1media',
#  '1rebel',
#  '1ring',
#  '1rp-media',
#  '1sdk',
#  '1spire',
#  '1st-choice-lawn-care',
#  '1st-merchant-funding',
#  '1stdibs',
#  '1stgig-com',
#  '1v1-draft-gaems',
#  '1world-online',
#  '2-ladoshki',
#  '2-minutes',
#  '2-ngage-u',
#  '2-observe',
#  '2-pro-media-group',
#  '20-20-gene-systems-inc',
#  '20-20-mobile',
#  '2080-media',
#  '20lines',
#  '20n',
#  '20x200',
#  '2100b-com-llc',
#  '21cake-food-co',
#  '21diamonds-india',
#  '21e6',
#  '21grams',
#  '21st-century-oncology',
#  '21vianet',
#  '22nd-century-group',
#  '22seeds',
#  '2345-com',
#  '2359-media',
#  '23andme',
#  '23press',
#  '24-7-card',
#  '24-7-customer',
#  '24-hour-pro-muscle-gym',
#  '24-media-network',
#  '24-quan',
#  '247-learning-private',
#  '247-techies',
#  '248-solidstate',
#  '24fab',
#  '24fundraiser-com',
#  '24h00',
#  '24i',
#  '24m-technologies',
#  '24me',
#  '24med-sp',
#  '24pagebooks',
#  '24symbols',
#  '24tidy',
#  '250ok',
#  '25eight',
#  '265-network',
#  '27-bards',
#  '27-perry',
#  '280-north',
#  '28msec',
#  '29west',
#  '2adpro-media-solutions',
#  '2b-angels',
#  '2c2p',
#  '2can',
#  '2catalyze',
#  '2checkout-com',
#  '2code-online',
#  '2crisk',
#  '2d2c',
#  '2degreesmobile',
#  '2dheat',
#  '2duche',
#  '2go-software-solutions',
#  '2heuresavant',
#  '2houses',
#  '2lemetry',
#  '2mee',
#  '2morrow-mobile',
#  '2nd-chance-solutions',
#  '2nd-screen-games',
#  '2nd-story-software-inc',
#  '2nd-watch',
#  '2ndnature',
#  '2nite2nite-net',
#  '2pm-technologies',
#  '2redbeans',
#  '2sms',
#  '2theloo',
#  '2threads',
#  '2u',
#  '2vancouver',
#  '2web-technologies',
#  '2win-solutions',
#  '2wire',
#  '3-day-blinds',
#  '3-four-5-group',
#  '3-kinds-of-ice',
#  '3-minute',
#  '3-v-biosciences',
#  '30-second-showcase',
#  '303-luxury-car-service',
#  '30secondstofly-claire',
#  '312-capital',
#  '31dover',
#  '321lend-inc',
#  '3225-films',
#  '33across',
#  '33coupons',
#  '360cities',
#  '360commerce',
#  '360fly-inc',
#  '360guanxi',
#  '360imaging',
#  '360incentives-com',
#  '360learning',
#  '360quan',
#  '360shop',
#  '360t',
#  '365-data-centers',
#  '365-docobites',
#  '365-good-teacher',
#  '365-retail-markets',
#  '365looks',
#  '365scores',
#  '365webcall',
#  '36kr',
#  '37coins',
#  '37mhealth',
#  '37signals',
#  '38-zeros',
#  '382-communications',
#  '39-health',
#  '3baysover',
#  '3c-interactive',
#  '3c-plus',
#  '3ci',
#  '3claps-the-fastest-baby-fashion',
#  '3clickemr-corporation',
#  '3clogic',
#  '3crowd-technologies',
#  '3d-4u',
#  '3d-biomatrix',
#  '3d-by-flow',
#  '3d-control-systems',
#  '3d-data',
#  '3d-eye-solutions',
#  '3d-forms',
#  '3d-future-vision-ii',
#  '3d-heights',
#  '3d-hubs',
#  '3d-industri-es',
#  '3d-intelligent-pathological-medical-image-solutions',
#  '3d-operations-inc',
#  '3d-product-imaging',
#  '3d-robotics',
#  '3d-simo-2',
#  '3d-sound-labs',
#  '3d-sports-technology',
#  '3d-systems',
#  '3d-vision-systems',
#  '3d4medical-com',
#  '3dbin',
#  '3dc',
#  '3dcart-shopping-cart-software',
#  '3dduo',
#  '3derm-systems',
#  '3diligent',
#  '3dim',
#  '3discovered',
#  '3divaz-2',
#  '3divaz-3',
#  '3divi-company',
#  '3dlt-com',
#  '3dmena',
#  '3dmgame',
#  '3dphotoworks',
#  '3dphy-com',
#  '3dplusme',
#  '3dprintus',
#  '3dr-laboratories',
#  '3dshook-2',
#  '3dsoc',
#  '3dt',
#  '3dvista',
#  '3floz-com',
#  '3funnel',
#  '3g-multimedia',
#  '3gear-systems',
#  '3guppies',
#  '3gv8-international-inc',
#  '3i-systems',
#  '3is',
#  '3jam',
#  '3keyit',
#  '3leaf',
#  '3lm',
#  '3nder',
#  '3p-biopharmaceuticals',
#  '3par',
#  '3pillar-global',
#  '3pl-central',
#  '3play-media',
#  '3point5-com',
#  '3pointdata',
#  '3power-energy-group',
#  '3rd-planet',
#  '3rdkind',
#  '3roam',
#  '3scale',
#  '3scan',
#  '3seventy',
#  '3si-security-systems',
#  '3sourcing',
#  '3sp-group',
#  '3sun',
#  '3ten8',
#  '3tier-environmental-forecast-group',
#  '3touch',
#  '3v-transaction-services',
#  '3vr-security',
#  '3ware',
#  '3x-systems',
#  '3yy-game-platform',
#  '4-33-creative-lab',
#  '4-animals-alsterscience-gmbh',
#  '4-antibody-ag',
#  '4-cast-broadcasting-corporation',
#  '4-tell',
#  '4-the-stars',
#  '40-partners-ltd',
#  '404-found',
#  '405labs',
#  '40billion-com',
#  '410-labs',
#  '41st-parameter',
#  '42',
#  '422-group',
#  '425-307-3480',
#  '42floors',
#  '42matters-ag',
#  '42networks',
#  '42race',
#  '43things',
#  '447-461-broadway-partners',
#  '44lab5',
#  '46elks',
#  '480-biomedical',
#  '48domain',
#  '490-entertainment',
#  '4blox',
#  '4c-insights',
#  '4cable-tv',
#  '4d-energetics',
#  '4d-molecular-therapeutics',
#  '4deep',
#  '4dk-technologies',
#  '4energy',
#  '4front-partners',
#  '4front-security',
#  '4home',
#  '4info',
#  '4less',
#  '4med-centra-medyczne',
#  '4meee',
#  '4moms',
#  '4plat',
#  '4psa',
#  '4runners-entertainment',
#  '4s91-com',
#  '4sc',
#  '4scotty-gmbh',
#  '4screens',
#  '4soils',
#  '4tech',
#  '4tell-solutions',
#  '4th-aspect',
#  '4th-office',
#  '4thetable',
#  '4tiitoo',
#  '4urspace',
#  '4vets',
#  '4wave',
#  '4x4-aviation',
#  '5-cups-and-some-sugar',
#  '5-examples',
#  '5-million-shoppers',
#  '5-minutes',
#  '5-oclock-records',
#  '5-screens-media',
#  '5-star-mobile',
#  '5-star-quarterback',
#  '5-stars-vacation-rentals',
#  '50-cubes',
#  '50-partners',
#  '500-luchadores',
#  '500friends',
#  '500indies',
#  '500px',
#  '500shops',
#  '51-auto',
#  '51-com',
#  '51-give',
#  '51-qiangzuo',
#  '5151tuan',
#  '5173-com',
#  '51credit-com',
#  '51cto',
#  '51edj',
#  '51edu',
#  '51hejia-com',
#  '51intern-com-2',
#  '51talk',
#  '51tour',
#  '51wan',
#  '51wofang-æ—\xa0å¿§æˆ‘æˆ¿',
#  '51yongche',
#  '51zhangdan',
#  '5211game',
#  '525j-com-cn',
#  '52masterworks',
#  '556-fitness',
#  '55social',
#  '55tuan-com',
#  '56-com',
#  '58-com',
#  '58daojia',
#  '591wed',
#  '59saniye',
#  '59sec-2',
#  '5app',
#  '5barz-international',
#  '5by',
#  '5dpnp',
#  '5ensesinfood',
#  '5gig',
#  '5i-sciences',
#  '5k-fans',
#  '5m-ventures',
#  '5min',
#  '5minutes',
#  '5nine-software',
#  '5o9',
#  '5rocks',
#  '5skills',
#  '5th-avenue-media',
#  '5th-finger',
#  '5th-planet-games',
#  '5to1',
#  '60frames-entertainment',
#  '60mo',
#  '64-pixels',
#  '640-labs',
#  '66-com',
#  '6apt',
#  '6connect',
#  '6cube',
#  '6d-global-technologies',
#  '6degrees',
#  '6ep',
#  '6fusion',
#  '6n-silicon',
#  '6px',
#  '6renyou-com',
#  '6rooms',
#  '6scan',
#  '6sense',
#  '6sensor-labs',
#  '6sicuro-it',
#  '6th-sense-analytics',
#  '6th-wave-innovations-corporation',
#  '6tribes',
#  '6wunderkinder',
#  '7-billion-people',
#  '7-bites',
#  '7-cups-of-tea',
#  '7-elements-studios',
#  '7-oaks-pharmaceutical',
#  '7-star-entertainment',
#  '700bike',
#  '71lbs',
#  '720',
#  '72798-com',
#  '72lux',
#  '72xuan',
#  '77-pieces',
#  '777-davis',
#  '79-group',
#  '7ac-technologies',
#  '7billionideas',
#  '7digital',
#  '7dnei-net',
#  '7fgame',
#  '7k7k-com',
#  '7mb-technologies',
#  '7park-data',
#  '7signal-solutions',
#  '7summits',
#  '7tm-pharma',
#  '7write',
#  '8-50-sports',
#  '8-inc',
#  '8-securities-limited',
#  '80-20-solutions',
#  '80-degrees-west',
#  '800-com',
#  '800app',
#  '800razors',
#  '8020publishing',
#  '8020select',
#  '80th-street-residence-facc-fund-i',
#  '818-sports-entertainment',
#  '8218-west-third',
#  '88-famibio',
#  '8868',
#  '88tc88',
#  '89-bits-entertainment-studio',
#  '8aweek',
#  '8bit-2',
#  '8digits',
#  '8dworld',
#  '8eighty-wear',
#  '8fit-fitness-for-the-rest-of-us',
#  '8hands',
#  '8i',
#  '8minutenergy-renewables',
#  '8packs',
#  '8th-story',
#  '8tracks',
#  '8trip',
#  '8villages',
#  '8wood',
#  '8x8-inc',
#  '9-plus-studio',
#  '908-devices',
#  '909c',
#  '90min',
#  '90sec-technologies',
#  '91-boyuan-wireles',
#  '91-golf',
#  '91-wireless',
#  '911-pets',
#  '911-view',
#  '915-labs-llc',
#  '9158-julur-com',
#  '91app',
#  '91datong-com',
#  '91jinrong',
#  '91mobiles',
#  '955-dreams',
#  '99-co',
#  '99-fahrenheit',
#  '99bill',
#  '99chairs',
#  '99cloud',
#  '99degrees-custom',
#  '99designs',
#  '99dresses',
#  '99drones',
#  '99gamers',
#  '99games-online-private-limited',
#  '99inn-cc',
#  '99jobs',
#  '99motos',
#  '99presents',
#  '99taojin-com',
#  '99taxis',
#  '99tests',
#  '99times-cn',
#  '9car-technology-llc',
#  '9cookies',
#  '9diamond',
#  '9facts',
#  '9flats',
#  '9flava',
#  '9gag',
#  '9lenses',
#  '9mile-labs',
#  '9sky-com',
#  '9slides',
#  '9star-research',
#  '9th-dimension-biotech',
#  '9tong-com',
#  '9you',
#  'a',
#  'a-76-technologies',
#  'a-a-custom-cornhole',
#  'a-a-manufacturing',
#  'a-and-a-travel-service',
#  'a-b-productions',
#  'a-better-tomorrow-treatment-center',
#  'a-bit-lucky',
#  'a-class-limos',
#  'a-crowd-of-monsters',
#  'a-curated-world',
#  'a-d-a-m-inc',
#  'a-d-propane',
#  'a-dance-for-me',
#  'a-e-complete-home-services',
#  'a-family-first-community-services',
#  'a-fourth-act',
#  'a-g-pharmaceutical',
#  'a-gas',
#  'a-green-nights-sleep',
#  'a-h-software-house',
#  'a-l-technology',
#  'a-la-mobile',
#  'a-life-medical',
#  'a-list-games',
#  'a-little-easier-recovery',
#  'a-little-world',
#  'a-max-technology',
#  'a-network',
#  'a-p-pharma',
#  'a-place-for-rover',
#  'a-pooches-pleasure',
#  'a-power-energy-generation',
#  'a-smarter-city',
#  'a-star',
#  'a-star-pets',
#  'a-suite-salon',
#  'a-tale-unfolds',
#  'a-tex',
#  'a-v-e-t-s-c-a-r-e',
#  'a-vida-feita-de-desconto',
#  'a-vu-media',
#  'a1-software-group',
#  'a10-capital',
#  'a10-networks',
#  'a123systems',
#  'a2b',
#  'a2t2',
#  'a2zlogix',
#  'a4-data',
#  'a4-data-technology-inc',
#  'a4vision',
#  'a8-digital-music',
#  'aa-carpooling-website',
#  'aa-party',
#  'aac-technologies-holdings',
#  'aaipharma-services',
#  'aalegal-cash-advance',
#  'aampp',
#  'aarden-pharmaceuticals',
#  'aardvark',
#  'aarki',
#  'aarohi-communication',
#  'aaron-andrews-apparel',
#  'aasaanjobs-com',
#  'aasonn',
#  'aastrom-biosciences',
#  'aat-communications',
#  'aatag',
#  'aava-mobile',
#  'aavlife',
#  'aavya-health',
#  'ab-group',
#  'ab-jb-properties-and-services',
#  'ab-microfinance-bank-nigeria',
#  'ab-tasty',
#  'aba-english',
#  'abaad-embodied-design-llc',
#  'abacast-inc',
#  'abacus-e-media',
#  'abacus-labs',
#  'abacuz-limited',
#  'abakan-inc',
#  'abakus',
#  'abaltat',
#  'abaris',
#  'abaris-investment-management',
#  'abarta-oil-gas',
#  'abattis-bioceuticals',
#  'abaxia',
#  'abaxx-technology',
#  'abazab',
#  'abb',
#  'abb-road',
#  'abbey-house-media',
#  'abbey-pharma',
#  'abbeypost',
#  'abboom',
#  'abbott',
#  'abbyy',
#  'abbyy-language-services',
#  'abc-data',
#  'abc-live',
#  'abc-management',
#  'abcam',
#  'abcdexperts',
#  'abcelex-technologies',
#  'abcellute',
#  'abcodia',
#  'abebooks',
#  'abeelo',
#  'abeja-inc-',
#  'abelite-design-automation-inc',
#  'abeo',
#  'abeome-corporation',
#  'abeona-therapeutics',
#  'abes-market',
#  'abfit-products',
#  'abgenomics',
#  'abhinav-outsourcings-pvt-ltd',
#  'abide-therapeutics',
#  'abidoc',
#  'abigail-stewart',
#  'ability-dynamics',
#  'ability-network',
#  'abilto',
#  'abimate-ee',
#  'abine',
#  'abingdon-health',
#  'abiobot',
#  'abiogenix',
#  'abionic',
#  'abios-gaming',
#  'abiquo-group',
#  'abizinabox',
#  'abk-biomedical',
#  'abl-farms',
#  'ablation-frontiers',
#  'ablative-solutions',
#  'able',
#  'able-device',
#  'able-imaging',
#  'able-planet',
#  'ablecloud',
#  'ablesky',
#  'ablexis',
#  'ablio',
#  'abloomy',
#  'ablynx',
#  'abo-data',
#  'abode',
#  'abodo',
#  'abound-logic',
#  'abound-resources',
#  'abound-solar',
#  'about-glamourrent-gmbh',
#  'about-web-reservations-international-web-reservations-international',
#  'aboutlife',
#  'aboutme',
#  'aboutmystar',
#  'aboutone',
#  'aboutourwork-com',
#  'aboutus-org',
#  'above-all-software',
#  'above-security',
#  'above-solutions',
#  'abovo42-corporation',
#  'abpathfinder',
#  'abra',
#  'abracon',
#  'abraresto',
#  'abreakplease',
#  'abreos-biosciences',
#  'abril',
#  'abroad101',
#  'abs',
#  'abs-medical',
#  'absentia',
#  'absmaterials',
#  'absolicon-solar-concentrator',
#  'absolutdata',
#  'absolute-antibody',
#  'absolute-commerce',
#  'absolute-sports-pvt-ltd',
#  'absolutely-training',
#  'absolvent',
#  'absorption-pharmaceuticals',
#  'absynth-biologics',
#  'abt-molecular-imaging',
#  'abtech-holdings',
#  'abtran',
#  'abukai',
#  'abundance-generation',
#  'abundant-closet',
#  'abury',
#  'abusix',
#  'abyz',
#  'abzena',
#  'abzorba-games',
#  'ac-holdco',
#  'ac-immune-sa',
#  'ac-moore-craft-store',
#  'acacia',
#  'acacia-communications',
#  'acacia-interactive',
#  'acacia-living',
#  'acacia-pharma',
#  'acacia-research',
#  'acacia-semiconductor',
#  'acacia-trading',
#  'academia',
#  'academia-edu',
#  'academia-rfid',
#  'academic-earth',
#  'academic-management-services',
#  'academica',
#  'academix-direct-go-internet-media',
#  'academize',
#  'academy-events-services',
#  'academy-of-inovation',
#  'academy123',
#  'acadia-pharmaceuticals',
#  'acadiasoft',
#  'acadient',
#  'acadine-technologies',
#  'acaia-corp',
#  'acal-energy',
#  'acal-enterprise-solutions',
#  'acamica',
#  'acarix',
#  'acast',
#  'acb-india-limited',
#  'accalio',
#  'acccess-technology-solutions',
#  'accedian-networks',
#  'accedo-broadband',
#  'accel-diagnostics',
#  'accela',
#  'accelalox',
#  'accelario',
#  'accelecare',
#  'acceleforce',
#  'accelera',
#  'accelera-innovations',
#  'accelerate-diagnostics',
#  'accelerate-mobile-apps',
#  'accelerated-io',
#  'accelerated-orthopedic-technologies',
#  'accelerated-pharma',
#  'accelerated-pictures',
#  'accelerated-technologies',
#  'accelerated-vision-group',
#  'accelerator-centre',
#  'accelerator-corp',
#  'accelereach',
#  'accelergy',
#  'accelerize-new-media',
#  'acceleron-pharma',
#  'accelgolf',
#  'accelight-networks',
#  'accelitec',
#  'accella-learning-llc',
#  'accellion',
#  'accellos',
#  'accelone',
#  'accelops',
#  'accelovation-2',
#  'accendo-technologies',
#  'accendo-therapeutics',
#  'accengage',
#  'accent',
#  'accent-custom-finishings-design-center',
#  'accent-media-ltd',
#  'accent-optical-technologies',
#  'accentia-biopharmaceuticals-inc',
#  'accentium-web',
#  'accenx-technologies',
#  'accept-software',
#  'acceptd',
#  'accera',
#  'accertify',
#  'access-bill-pay-services',
#  'access-closure',
#  'access-information-management',
#  'access-integrated-healthcare',
#  'access-intelligence',
#  'access-media',
#  'access-mediquip',
#  'access-mobile',
#  'access-northeast',
#  'access-pharmaceuticals',
#  'access-point',
#  'access-psychiatry-solutions',
#  'access-scientific',
#  'access-sports-media-2',
#  'access-systems',
#  'access-uk',
#  'accessbio',
#  'accessdata',
#  'accessdna',
#  'accesslan-communications',
#  'accessnetwork',
#  'accessory-addict-society',
#  'accesspay',
#  'accio-energy',
#  'accion-international',
#  'accion-systems',
#  'accion-texas',
#  'accipiter',
#  'accipiter-radar',
#  'accipiter-systems',
#  'acclaim-games',
#  'acclaimd',
#  'acclarent',
#  'acclaris-holdings',
#  'acco-brands',
#  'acco-sa',
#  'acco-semiconductor',
#  'accolade',
#  'accolo',
#  'accompany',
#  'accord',
#  'accord-biomaterials',
#  'accordent-technologies',
#  'accordion-health',
#  'accountable',
#  'accounting-saas-japan',
#  'accountnow',
#  'accredible',
#  'accreon',
#  'accriva-diagnostics',
#  'accrue-search-concepts-dba-boounce',
#  'accruent',
#  'accruit',
#  'accu-break-pharmaceuticals',
#  'accubuild-it',
#  'accudial-pharmaceutical',
#  'accudraft',
#  'accuhealth-partners',
#  'accuitis',
#  'acculitx',
#  'accumed-technologies',
#  'accumedia',
#  'accumen',
#  'accumetrics',
#  'accumulate',
#  'accumuli-security',
#  'accunostics',
#  'accupal',
#  'accupass',
#  'accupost-corporation',
#  'accuradio',
#  'accurate-group',
#  'accurence',
#  'accurev',
#  'accuri-cytometers',
#  'accuric',
#  'accuris-networks',
#  'accusilicon',
#  'accusoft-pegasus',
#  'accutherm-systems',
#  'accutrainee',
#  'accuvant',
#  'accuvein',
#  'accuwater',
#  'ace',
#  'ace-2',
#  'ace-comm',
#  'ace-consensus',
#  'ace-film-productions',
#  'ace-health',
#  'ace-learning-company-inc',
#  'ace-metrix',
#  'ace-portal',
#  'acea-bio',
#  'aceable',
#  'acelero-learning',
#  'acell',
#  'acelrx-pharmaceuticals',
#  'acempire',
#  'acendi-interactive',
#  'acer',
#  'acer-therapeutics',
#  'acera-surgical',
#  'aceris-3d-inspection',
#  'acerta-pharma',
#  'acesion-pharma',
#  'acesis',
#  'acesobee',
#  'acetylon-pharmaceuticals',
#  'aceva-technologies',
#  'achala',
#  'achaogen',
#  'achates-power',
#  'acheev-it',
#  'acheive-cca',
#  'achelios-therapeutics',
#  'achica',
#  'achieve-financial-services',
#  'achieve-lending',
#  'achieve-x',
#  'achieve3000',
#  'achieved-co',
#  'achieveit-online',
#  'achievemint',
#  ...]

# %%
companies['companyname']=companyname
companies.head(2)
# Out:
#                 permalink      name            homepage_url  \
# 0     /Organization/-Fame     #fame      http://livfame.com
# 1  /Organization/-Qounter  :Qounter  http://www.qounter.com
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
#
#   state_code      region           city  founded_at companyname
# 0         16      Mumbai         Mumbai         NaN       -fame
# 1         DE  DE - Other  Delaware City  04-09-2014    -qounter

# %%
#companies['permalink']=companies['permalink'].dropna()
#companies['permalink']
companyname=[]
for i in companies['companyname']:
    companyname.append(i.replace('-',''))
companyname
# Out:
# ['fame',
#  'qounter',
#  'theoneoftheminc',
#  '06com',
#  '004technologies',
#  '01gamestechnology',
#  '0ndinebiomedicalinc',
#  '0xdata',
#  '1',
#  '123listo',
#  '14all',
#  '1618technology',
#  '1800dentist',
#  '1800doctors',
#  '1800publicrelationsinc',
#  '1mainstream',
#  '1of99',
#  '1020media',
#  '10minuteswith',
#  '1000corks',
#  '1000markets',
#  '1000chi',
#  '1000lookz',
#  '1000memories',
#  '1000museumscom',
#  '1001menus',
#  '1001pharmaciescom',
#  '1006tv',
#  '100dutv',
#  '100ecom',
#  '100health',
#  '100plus',
#  '1010data',
#  '10alike',
#  '10bestthings',
#  '10k2',
#  '10sec',
#  '10secondssoftware',
#  '10six',
#  '10tracks2',
#  '10xgenomics',
#  '10xtechnologies',
#  '10x10room',
#  '10â°north',
#  '11health',
#  '115networkdisks',
#  '117go',
#  '11isolutions',
#  '12labs',
#  '12starsurvival',
#  '120sports',
#  '121rentals',
#  '121cast',
#  '121nexus',
#  '1234enter',
#  '123contactform',
#  '123fengcom',
#  '123greetings',
#  '123people',
#  '1248',
#  '128technology',
#  '12bis',
#  '12cm',
#  '12return',
#  '12society',
#  '1366technologies',
#  '139shop',
#  '13thlab',
#  '140proof',
#  '140fire',
#  '1417',
#  '15fen',
#  '15five',
#  '15minutesnow',
#  '15shopstop',
#  '16milesolutions',
#  '169st',
#  '16labinc',
#  '16wifi',
#  '17media',
#  '170systems',
#  '17hats',
#  '17ucn',
#  '17zuoye',
#  '1800diapers',
#  '180solutions',
#  '1871',
#  '19pay',
#  '1bib',
#  '1bog',
#  '1ccompany',
#  '1calendar',
#  '1cast',
#  '1click',
#  '1cloudstarasia',
#  '1commmedical',
#  '1d4pty',
#  '1day1song',
#  '1daylater',
#  '1daymakeover',
#  '1doc3',
#  '1docway',
#  '1energysystems',
#  '1eq',
#  '1jiajie',
#  '1lay',
#  '1lifehealthcare',
#  '1mind',
#  '1mpactrevolutionpoweringhelpfreelyorg',
#  '1mxians',
#  '1o1media',
#  '1rebel',
#  '1ring',
#  '1rpmedia',
#  '1sdk',
#  '1spire',
#  '1stchoicelawncare',
#  '1stmerchantfunding',
#  '1stdibs',
#  '1stgigcom',
#  '1v1draftgaems',
#  '1worldonline',
#  '2ladoshki',
#  '2minutes',
#  '2ngageu',
#  '2observe',
#  '2promediagroup',
#  '2020genesystemsinc',
#  '2020mobile',
#  '2080media',
#  '20lines',
#  '20n',
#  '20x200',
#  '2100bcomllc',
#  '21cakefoodco',
#  '21diamondsindia',
#  '21e6',
#  '21grams',
#  '21stcenturyoncology',
#  '21vianet',
#  '22ndcenturygroup',
#  '22seeds',
#  '2345com',
#  '2359media',
#  '23andme',
#  '23press',
#  '247card',
#  '247customer',
#  '24hourpromusclegym',
#  '24medianetwork',
#  '24quan',
#  '247learningprivate',
#  '247techies',
#  '248solidstate',
#  '24fab',
#  '24fundraisercom',
#  '24h00',
#  '24i',
#  '24mtechnologies',
#  '24me',
#  '24medsp',
#  '24pagebooks',
#  '24symbols',
#  '24tidy',
#  '250ok',
#  '25eight',
#  '265network',
#  '27bards',
#  '27perry',
#  '280north',
#  '28msec',
#  '29west',
#  '2adpromediasolutions',
#  '2bangels',
#  '2c2p',
#  '2can',
#  '2catalyze',
#  '2checkoutcom',
#  '2codeonline',
#  '2crisk',
#  '2d2c',
#  '2degreesmobile',
#  '2dheat',
#  '2duche',
#  '2gosoftwaresolutions',
#  '2heuresavant',
#  '2houses',
#  '2lemetry',
#  '2mee',
#  '2morrowmobile',
#  '2ndchancesolutions',
#  '2ndscreengames',
#  '2ndstorysoftwareinc',
#  '2ndwatch',
#  '2ndnature',
#  '2nite2nitenet',
#  '2pmtechnologies',
#  '2redbeans',
#  '2sms',
#  '2theloo',
#  '2threads',
#  '2u',
#  '2vancouver',
#  '2webtechnologies',
#  '2winsolutions',
#  '2wire',
#  '3dayblinds',
#  '3four5group',
#  '3kindsofice',
#  '3minute',
#  '3vbiosciences',
#  '30secondshowcase',
#  '303luxurycarservice',
#  '30secondstoflyclaire',
#  '312capital',
#  '31dover',
#  '321lendinc',
#  '3225films',
#  '33across',
#  '33coupons',
#  '360cities',
#  '360commerce',
#  '360flyinc',
#  '360guanxi',
#  '360imaging',
#  '360incentivescom',
#  '360learning',
#  '360quan',
#  '360shop',
#  '360t',
#  '365datacenters',
#  '365docobites',
#  '365goodteacher',
#  '365retailmarkets',
#  '365looks',
#  '365scores',
#  '365webcall',
#  '36kr',
#  '37coins',
#  '37mhealth',
#  '37signals',
#  '38zeros',
#  '382communications',
#  '39health',
#  '3baysover',
#  '3cinteractive',
#  '3cplus',
#  '3ci',
#  '3clapsthefastestbabyfashion',
#  '3clickemrcorporation',
#  '3clogic',
#  '3crowdtechnologies',
#  '3d4u',
#  '3dbiomatrix',
#  '3dbyflow',
#  '3dcontrolsystems',
#  '3ddata',
#  '3deyesolutions',
#  '3dforms',
#  '3dfuturevisionii',
#  '3dheights',
#  '3dhubs',
#  '3dindustries',
#  '3dintelligentpathologicalmedicalimagesolutions',
#  '3doperationsinc',
#  '3dproductimaging',
#  '3drobotics',
#  '3dsimo2',
#  '3dsoundlabs',
#  '3dsportstechnology',
#  '3dsystems',
#  '3dvisionsystems',
#  '3d4medicalcom',
#  '3dbin',
#  '3dc',
#  '3dcartshoppingcartsoftware',
#  '3dduo',
#  '3dermsystems',
#  '3diligent',
#  '3dim',
#  '3discovered',
#  '3divaz2',
#  '3divaz3',
#  '3divicompany',
#  '3dltcom',
#  '3dmena',
#  '3dmgame',
#  '3dphotoworks',
#  '3dphycom',
#  '3dplusme',
#  '3dprintus',
#  '3drlaboratories',
#  '3dshook2',
#  '3dsoc',
#  '3dt',
#  '3dvista',
#  '3flozcom',
#  '3funnel',
#  '3gmultimedia',
#  '3gearsystems',
#  '3guppies',
#  '3gv8internationalinc',
#  '3isystems',
#  '3is',
#  '3jam',
#  '3keyit',
#  '3leaf',
#  '3lm',
#  '3nder',
#  '3pbiopharmaceuticals',
#  '3par',
#  '3pillarglobal',
#  '3plcentral',
#  '3playmedia',
#  '3point5com',
#  '3pointdata',
#  '3powerenergygroup',
#  '3rdplanet',
#  '3rdkind',
#  '3roam',
#  '3scale',
#  '3scan',
#  '3seventy',
#  '3sisecuritysystems',
#  '3sourcing',
#  '3spgroup',
#  '3sun',
#  '3ten8',
#  '3tierenvironmentalforecastgroup',
#  '3touch',
#  '3vtransactionservices',
#  '3vrsecurity',
#  '3ware',
#  '3xsystems',
#  '3yygameplatform',
#  '433creativelab',
#  '4animalsalstersciencegmbh',
#  '4antibodyag',
#  '4castbroadcastingcorporation',
#  '4tell',
#  '4thestars',
#  '40partnersltd',
#  '404found',
#  '405labs',
#  '40billioncom',
#  '410labs',
#  '41stparameter',
#  '42',
#  '422group',
#  '4253073480',
#  '42floors',
#  '42mattersag',
#  '42networks',
#  '42race',
#  '43things',
#  '447461broadwaypartners',
#  '44lab5',
#  '46elks',
#  '480biomedical',
#  '48domain',
#  '490entertainment',
#  '4blox',
#  '4cinsights',
#  '4cabletv',
#  '4denergetics',
#  '4dmoleculartherapeutics',
#  '4deep',
#  '4dktechnologies',
#  '4energy',
#  '4frontpartners',
#  '4frontsecurity',
#  '4home',
#  '4info',
#  '4less',
#  '4medcentramedyczne',
#  '4meee',
#  '4moms',
#  '4plat',
#  '4psa',
#  '4runnersentertainment',
#  '4s91com',
#  '4sc',
#  '4scottygmbh',
#  '4screens',
#  '4soils',
#  '4tech',
#  '4tellsolutions',
#  '4thaspect',
#  '4thoffice',
#  '4thetable',
#  '4tiitoo',
#  '4urspace',
#  '4vets',
#  '4wave',
#  '4x4aviation',
#  '5cupsandsomesugar',
#  '5examples',
#  '5millionshoppers',
#  '5minutes',
#  '5oclockrecords',
#  '5screensmedia',
#  '5starmobile',
#  '5starquarterback',
#  '5starsvacationrentals',
#  '50cubes',
#  '50partners',
#  '500luchadores',
#  '500friends',
#  '500indies',
#  '500px',
#  '500shops',
#  '51auto',
#  '51com',
#  '51give',
#  '51qiangzuo',
#  '5151tuan',
#  '5173com',
#  '51creditcom',
#  '51cto',
#  '51edj',
#  '51edu',
#  '51hejiacom',
#  '51interncom2',
#  '51talk',
#  '51tour',
#  '51wan',
#  '51wofangæ—\xa0å¿§æˆ‘æˆ¿',
#  '51yongche',
#  '51zhangdan',
#  '5211game',
#  '525jcomcn',
#  '52masterworks',
#  '556fitness',
#  '55social',
#  '55tuancom',
#  '56com',
#  '58com',
#  '58daojia',
#  '591wed',
#  '59saniye',
#  '59sec2',
#  '5app',
#  '5barzinternational',
#  '5by',
#  '5dpnp',
#  '5ensesinfood',
#  '5gig',
#  '5isciences',
#  '5kfans',
#  '5mventures',
#  '5min',
#  '5minutes',
#  '5ninesoftware',
#  '5o9',
#  '5rocks',
#  '5skills',
#  '5thavenuemedia',
#  '5thfinger',
#  '5thplanetgames',
#  '5to1',
#  '60framesentertainment',
#  '60mo',
#  '64pixels',
#  '640labs',
#  '66com',
#  '6apt',
#  '6connect',
#  '6cube',
#  '6dglobaltechnologies',
#  '6degrees',
#  '6ep',
#  '6fusion',
#  '6nsilicon',
#  '6px',
#  '6renyoucom',
#  '6rooms',
#  '6scan',
#  '6sense',
#  '6sensorlabs',
#  '6sicuroit',
#  '6thsenseanalytics',
#  '6thwaveinnovationscorporation',
#  '6tribes',
#  '6wunderkinder',
#  '7billionpeople',
#  '7bites',
#  '7cupsoftea',
#  '7elementsstudios',
#  '7oakspharmaceutical',
#  '7starentertainment',
#  '700bike',
#  '71lbs',
#  '720',
#  '72798com',
#  '72lux',
#  '72xuan',
#  '77pieces',
#  '777davis',
#  '79group',
#  '7actechnologies',
#  '7billionideas',
#  '7digital',
#  '7dneinet',
#  '7fgame',
#  '7k7kcom',
#  '7mbtechnologies',
#  '7parkdata',
#  '7signalsolutions',
#  '7summits',
#  '7tmpharma',
#  '7write',
#  '850sports',
#  '8inc',
#  '8securitieslimited',
#  '8020solutions',
#  '80degreeswest',
#  '800com',
#  '800app',
#  '800razors',
#  '8020publishing',
#  '8020select',
#  '80thstreetresidencefaccfundi',
#  '818sportsentertainment',
#  '8218westthird',
#  '88famibio',
#  '8868',
#  '88tc88',
#  '89bitsentertainmentstudio',
#  '8aweek',
#  '8bit2',
#  '8digits',
#  '8dworld',
#  '8eightywear',
#  '8fitfitnessfortherestofus',
#  '8hands',
#  '8i',
#  '8minutenergyrenewables',
#  '8packs',
#  '8thstory',
#  '8tracks',
#  '8trip',
#  '8villages',
#  '8wood',
#  '8x8inc',
#  '9plusstudio',
#  '908devices',
#  '909c',
#  '90min',
#  '90sectechnologies',
#  '91boyuanwireles',
#  '91golf',
#  '91wireless',
#  '911pets',
#  '911view',
#  '915labsllc',
#  '9158julurcom',
#  '91app',
#  '91datongcom',
#  '91jinrong',
#  '91mobiles',
#  '955dreams',
#  '99co',
#  '99fahrenheit',
#  '99bill',
#  '99chairs',
#  '99cloud',
#  '99degreescustom',
#  '99designs',
#  '99dresses',
#  '99drones',
#  '99gamers',
#  '99gamesonlineprivatelimited',
#  '99inncc',
#  '99jobs',
#  '99motos',
#  '99presents',
#  '99taojincom',
#  '99taxis',
#  '99tests',
#  '99timescn',
#  '9cartechnologyllc',
#  '9cookies',
#  '9diamond',
#  '9facts',
#  '9flats',
#  '9flava',
#  '9gag',
#  '9lenses',
#  '9milelabs',
#  '9skycom',
#  '9slides',
#  '9starresearch',
#  '9thdimensionbiotech',
#  '9tongcom',
#  '9you',
#  'a',
#  'a76technologies',
#  'aacustomcornhole',
#  'aamanufacturing',
#  'aandatravelservice',
#  'abproductions',
#  'abettertomorrowtreatmentcenter',
#  'abitlucky',
#  'aclasslimos',
#  'acrowdofmonsters',
#  'acuratedworld',
#  'adaminc',
#  'adpropane',
#  'adanceforme',
#  'aecompletehomeservices',
#  'afamilyfirstcommunityservices',
#  'afourthact',
#  'agpharmaceutical',
#  'agas',
#  'agreennightssleep',
#  'ahsoftwarehouse',
#  'altechnology',
#  'alamobile',
#  'alifemedical',
#  'alistgames',
#  'alittleeasierrecovery',
#  'alittleworld',
#  'amaxtechnology',
#  'anetwork',
#  'appharma',
#  'aplaceforrover',
#  'apoochespleasure',
#  'apowerenergygeneration',
#  'asmartercity',
#  'astar',
#  'astarpets',
#  'asuitesalon',
#  'ataleunfolds',
#  'atex',
#  'avetscare',
#  'avidafeitadedesconto',
#  'avumedia',
#  'a1softwaregroup',
#  'a10capital',
#  'a10networks',
#  'a123systems',
#  'a2b',
#  'a2t2',
#  'a2zlogix',
#  'a4data',
#  'a4datatechnologyinc',
#  'a4vision',
#  'a8digitalmusic',
#  'aacarpoolingwebsite',
#  'aaparty',
#  'aactechnologiesholdings',
#  'aaipharmaservices',
#  'aalegalcashadvance',
#  'aampp',
#  'aardenpharmaceuticals',
#  'aardvark',
#  'aarki',
#  'aarohicommunication',
#  'aaronandrewsapparel',
#  'aasaanjobscom',
#  'aasonn',
#  'aastrombiosciences',
#  'aatcommunications',
#  'aatag',
#  'aavamobile',
#  'aavlife',
#  'aavyahealth',
#  'abgroup',
#  'abjbpropertiesandservices',
#  'abmicrofinancebanknigeria',
#  'abtasty',
#  'abaenglish',
#  'abaadembodieddesignllc',
#  'abacastinc',
#  'abacusemedia',
#  'abacuslabs',
#  'abacuzlimited',
#  'abakaninc',
#  'abakus',
#  'abaltat',
#  'abaris',
#  'abarisinvestmentmanagement',
#  'abartaoilgas',
#  'abattisbioceuticals',
#  'abaxia',
#  'abaxxtechnology',
#  'abazab',
#  'abb',
#  'abbroad',
#  'abbeyhousemedia',
#  'abbeypharma',
#  'abbeypost',
#  'abboom',
#  'abbott',
#  'abbyy',
#  'abbyylanguageservices',
#  'abcdata',
#  'abclive',
#  'abcmanagement',
#  'abcam',
#  'abcdexperts',
#  'abcelextechnologies',
#  'abcellute',
#  'abcodia',
#  'abebooks',
#  'abeelo',
#  'abejainc',
#  'abelitedesignautomationinc',
#  'abeo',
#  'abeomecorporation',
#  'abeonatherapeutics',
#  'abesmarket',
#  'abfitproducts',
#  'abgenomics',
#  'abhinavoutsourcingspvtltd',
#  'abidetherapeutics',
#  'abidoc',
#  'abigailstewart',
#  'abilitydynamics',
#  'abilitynetwork',
#  'abilto',
#  'abimateee',
#  'abine',
#  'abingdonhealth',
#  'abiobot',
#  'abiogenix',
#  'abionic',
#  'abiosgaming',
#  'abiquogroup',
#  'abizinabox',
#  'abkbiomedical',
#  'ablfarms',
#  'ablationfrontiers',
#  'ablativesolutions',
#  'able',
#  'abledevice',
#  'ableimaging',
#  'ableplanet',
#  'ablecloud',
#  'ablesky',
#  'ablexis',
#  'ablio',
#  'abloomy',
#  'ablynx',
#  'abodata',
#  'abode',
#  'abodo',
#  'aboundlogic',
#  'aboundresources',
#  'aboundsolar',
#  'aboutglamourrentgmbh',
#  'aboutwebreservationsinternationalwebreservationsinternational',
#  'aboutlife',
#  'aboutme',
#  'aboutmystar',
#  'aboutone',
#  'aboutourworkcom',
#  'aboutusorg',
#  'aboveallsoftware',
#  'abovesecurity',
#  'abovesolutions',
#  'abovo42corporation',
#  'abpathfinder',
#  'abra',
#  'abracon',
#  'abraresto',
#  'abreakplease',
#  'abreosbiosciences',
#  'abril',
#  'abroad101',
#  'abs',
#  'absmedical',
#  'absentia',
#  'absmaterials',
#  'absoliconsolarconcentrator',
#  'absolutdata',
#  'absoluteantibody',
#  'absolutecommerce',
#  'absolutesportspvtltd',
#  'absolutelytraining',
#  'absolvent',
#  'absorptionpharmaceuticals',
#  'absynthbiologics',
#  'abtmolecularimaging',
#  'abtechholdings',
#  'abtran',
#  'abukai',
#  'abundancegeneration',
#  'abundantcloset',
#  'abury',
#  'abusix',
#  'abyz',
#  'abzena',
#  'abzorbagames',
#  'acholdco',
#  'acimmunesa',
#  'acmoorecraftstore',
#  'acacia',
#  'acaciacommunications',
#  'acaciainteractive',
#  'acacialiving',
#  'acaciapharma',
#  'acaciaresearch',
#  'acaciasemiconductor',
#  'acaciatrading',
#  'academia',
#  'academiaedu',
#  'academiarfid',
#  'academicearth',
#  'academicmanagementservices',
#  'academica',
#  'academixdirectgointernetmedia',
#  'academize',
#  'academyeventsservices',
#  'academyofinovation',
#  'academy123',
#  'acadiapharmaceuticals',
#  'acadiasoft',
#  'acadient',
#  'acadinetechnologies',
#  'acaiacorp',
#  'acalenergy',
#  'acalenterprisesolutions',
#  'acamica',
#  'acarix',
#  'acast',
#  'acbindialimited',
#  'accalio',
#  'acccesstechnologysolutions',
#  'accediannetworks',
#  'accedobroadband',
#  'acceldiagnostics',
#  'accela',
#  'accelalox',
#  'accelario',
#  'accelecare',
#  'acceleforce',
#  'accelera',
#  'accelerainnovations',
#  'acceleratediagnostics',
#  'acceleratemobileapps',
#  'acceleratedio',
#  'acceleratedorthopedictechnologies',
#  'acceleratedpharma',
#  'acceleratedpictures',
#  'acceleratedtechnologies',
#  'acceleratedvisiongroup',
#  'acceleratorcentre',
#  'acceleratorcorp',
#  'accelereach',
#  'accelergy',
#  'accelerizenewmedia',
#  'acceleronpharma',
#  'accelgolf',
#  'accelightnetworks',
#  'accelitec',
#  'accellalearningllc',
#  'accellion',
#  'accellos',
#  'accelone',
#  'accelops',
#  'accelovation2',
#  'accendotechnologies',
#  'accendotherapeutics',
#  'accengage',
#  'accent',
#  'accentcustomfinishingsdesigncenter',
#  'accentmedialtd',
#  'accentopticaltechnologies',
#  'accentiabiopharmaceuticalsinc',
#  'accentiumweb',
#  'accenxtechnologies',
#  'acceptsoftware',
#  'acceptd',
#  'accera',
#  'accertify',
#  'accessbillpayservices',
#  'accessclosure',
#  'accessinformationmanagement',
#  'accessintegratedhealthcare',
#  'accessintelligence',
#  'accessmedia',
#  'accessmediquip',
#  'accessmobile',
#  'accessnortheast',
#  'accesspharmaceuticals',
#  'accesspoint',
#  'accesspsychiatrysolutions',
#  'accessscientific',
#  'accesssportsmedia2',
#  'accesssystems',
#  'accessuk',
#  'accessbio',
#  'accessdata',
#  'accessdna',
#  'accesslancommunications',
#  'accessnetwork',
#  'accessoryaddictsociety',
#  'accesspay',
#  'accioenergy',
#  'accioninternational',
#  'accionsystems',
#  'acciontexas',
#  'accipiter',
#  'accipiterradar',
#  'accipitersystems',
#  'acclaimgames',
#  'acclaimd',
#  'acclarent',
#  'acclarisholdings',
#  'accobrands',
#  'accosa',
#  'accosemiconductor',
#  'accolade',
#  'accolo',
#  'accompany',
#  'accord',
#  'accordbiomaterials',
#  'accordenttechnologies',
#  'accordionhealth',
#  'accountable',
#  'accountingsaasjapan',
#  'accountnow',
#  'accredible',
#  'accreon',
#  'accrivadiagnostics',
#  'accruesearchconceptsdbaboounce',
#  'accruent',
#  'accruit',
#  'accubreakpharmaceuticals',
#  'accubuildit',
#  'accudialpharmaceutical',
#  'accudraft',
#  'accuhealthpartners',
#  'accuitis',
#  'acculitx',
#  'accumedtechnologies',
#  'accumedia',
#  'accumen',
#  'accumetrics',
#  'accumulate',
#  'accumulisecurity',
#  'accunostics',
#  'accupal',
#  'accupass',
#  'accupostcorporation',
#  'accuradio',
#  'accurategroup',
#  'accurence',
#  'accurev',
#  'accuricytometers',
#  'accuric',
#  'accurisnetworks',
#  'accusilicon',
#  'accusoftpegasus',
#  'accuthermsystems',
#  'accutrainee',
#  'accuvant',
#  'accuvein',
#  'accuwater',
#  'ace',
#  'ace2',
#  'acecomm',
#  'aceconsensus',
#  'acefilmproductions',
#  'acehealth',
#  'acelearningcompanyinc',
#  'acemetrix',
#  'aceportal',
#  'aceabio',
#  'aceable',
#  'acelerolearning',
#  'acell',
#  'acelrxpharmaceuticals',
#  'acempire',
#  'acendiinteractive',
#  'acer',
#  'acertherapeutics',
#  'acerasurgical',
#  'aceris3dinspection',
#  'acertapharma',
#  'acesionpharma',
#  'acesis',
#  'acesobee',
#  'acetylonpharmaceuticals',
#  'acevatechnologies',
#  'achala',
#  'achaogen',
#  'achatespower',
#  'acheevit',
#  'acheivecca',
#  'acheliostherapeutics',
#  'achica',
#  'achievefinancialservices',
#  'achievelending',
#  'achievex',
#  'achieve3000',
#  'achievedco',
#  'achieveitonline',
#  'achievemint',
#  ...]

# %%
companies['companyname']=companyname
companies.head(2)
# Out:
#                 permalink      name            homepage_url  \
# 0     /Organization/-Fame     #fame      http://livfame.com
# 1  /Organization/-Qounter  :Qounter  http://www.qounter.com
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
#
#   state_code      region           city  founded_at companyname
# 0         16      Mumbai         Mumbai         NaN        fame
# 1         DE  DE - Other  Delaware City  04-09-2014     qounter

# %%
companies['companyname'].unique()
# Out:
# array(['fame', 'qounter', 'theoneoftheminc', ..., 'ã\x81eron', 'ã”asys2',
#        'ä°novatiffreklamvetanä±tä±mhizmetleritic'], dtype=object)

# %%
companies['companyname'].nunique()
# Out:
# 66290

# %%
#1.how many unique companies are present in rounds2?
rounds2=pd.read_csv('rounds2.csv',encoding='ansi')

# %%
rounds2.head(2)
# Out:
#         company_permalink                          funding_round_permalink  \
# 0     /organization/-fame  /funding-round/9a01d05418af9f794eebff7ace91f638
# 1  /ORGANIZATION/-QOUNTER  /funding-round/22dacff496eb7acb2b901dec1dfe5633
#
#   funding_round_type funding_round_code   funded_at  raised_amount_usd
# 0            venture                  B  05-01-2015         10000000.0
# 1            venture                  A  14-10-2014                NaN

# %%
rounds2.shape
# Out:
# (114949, 6)

# %%
rounds2.columns
# Out:
# Index(['company_permalink', 'funding_round_permalink', 'funding_round_type',
#        'funding_round_code', 'funded_at', 'raised_amount_usd'],
#       dtype='object')

# %%
rounds2['company_permalink'].value_counts()
# Out:
# /ORGANIZATION/SOLARFLARE             10
# /organization/vocalocity              9
# /organization/semprius                9
# /ORGANIZATION/QUELLAN                 9
# /organization/solarflare              9
#                                      ..
# /ORGANIZATION/SUKSH-TECH              1
# /ORGANIZATION/IVENGO                  1
# /ORGANIZATION/CODEWARS                1
# /organization/nupark                  1
# /ORGANIZATION/INTERNET-MEDIA-LABS     1
# Name: company_permalink, Length: 90247, dtype: int64

# %%
rounds2['companyname']=rounds2['company_permalink'].str.strip()
rounds2['company_permalink'].unique()
# Out:
# array(['/organization/-fame', '/ORGANIZATION/-QOUNTER',
#        '/organization/-qounter', ..., '/organization/ã\x81eron',
#        '/ORGANIZATION/Ã”ASYS-2',
#        '/organization/ä°novatiff-reklam-ve-tanä±tä±m-hizmetleri-tic'],
#       dtype=object)

# %%
rounds2['companyname']=rounds2['company_permalink'].str.lower()
rounds2['companyname'].unique()
# Out:
# array(['/organization/-fame', '/organization/-qounter',
#        '/organization/-the-one-of-them-inc-', ...,
#        '/organization/ã\x81eron', '/organization/ã”asys-2',
#        '/organization/ä°novatiff-reklam-ve-tanä±tä±m-hizmetleri-tic'],
#       dtype=object)

# %%
rounds2['companyname'][0]
# Out:
# '/organization/-fame'

# %%
rounds2['companyname'][0].replace('-','')
# Out:
# '/organization/fame'

# %%
companyname=[]
for i in rounds2['companyname']:
    companyname.append(i.split('/')[2])
companyname
# Out:
# ['-fame',
#  '-qounter',
#  '-qounter',
#  '-the-one-of-them-inc-',
#  '0-6-com',
#  '004-technologies',
#  '01games-technology',
#  '0ndine-biomedical-inc',
#  '0ndine-biomedical-inc',
#  '0xdata',
#  '0xdata',
#  '0xdata',
#  '0xdata',
#  '1',
#  '1',
#  '1',
#  '1-2-3-listo',
#  '1-4-all',
#  '1-618-technology',
#  '1-800-dentist',
#  '1-800-doctors',
#  '1-800-publicrelations-inc-',
#  '1-mainstream',
#  '1-of-99',
#  '10-20-media',
#  '10-20-media',
#  '10-20-media',
#  '10-20-media',
#  '10-minutes-with',
#  '10-minutes-with',
#  '1000-corks',
#  '1000-markets',
#  '1000chi',
#  '1000lookz',
#  '1000memories',
#  '1000memories',
#  '1000museums-com',
#  '1000museums-com',
#  '1000museums-com',
#  '1000museums-com',
#  '1000museums-com',
#  '1000museums-com',
#  '1000museums-com',
#  '1000museums-com',
#  '1000museums-com',
#  '1001-menus',
#  '1001-menus',
#  '1001-menus',
#  '1001-menus',
#  '1001-menus',
#  '1001pharmacies-com',
#  '1006-tv',
#  '1006-tv',
#  '1006-tv',
#  '100du-tv',
#  '100du-tv',
#  '100e-com',
#  '100e-com',
#  '100health',
#  '100health',
#  '100plus',
#  '100plus',
#  '1010data',
#  '10alike',
#  '10alike',
#  '10bestthings',
#  '10k-2',
#  '10sec',
#  '10sec',
#  '10seconds-software',
#  '10six',
#  '10tracks-2',
#  '10tracks-2',
#  '10x-genomics',
#  '10x-technologies',
#  '10x-technologies',
#  '10x10-room',
#  '10â°north',
#  '11-health',
#  '115-network-disks',
#  '117go',
#  '11i-solutions',
#  '12-labs',
#  '12-star-survival',
#  '120-sports',
#  '121-rentals',
#  '121cast',
#  '121cast',
#  '121cast',
#  '121nexus',
#  '121nexus',
#  '121nexus',
#  '121nexus',
#  '121nexus',
#  '121nexus',
#  '1234enter',
#  '1234enter',
#  '123contactform',
#  '123contactform',
#  '123feng-com',
#  '123greetings',
#  '123people',
#  '1248',
#  '128-technology',
#  '12bis',
#  '12cm',
#  '12return',
#  '12society',
#  '1366-technologies',
#  '1366-technologies',
#  '1366-technologies',
#  '1366-technologies',
#  '1366-technologies',
#  '1366-technologies',
#  '1366-technologies',
#  '1366-technologies',
#  '1366-technologies',
#  '139shop',
#  '13th-lab',
#  '140-proof',
#  '140-proof',
#  '140fire',
#  '1417',
#  '15fen',
#  '15five',
#  '15five',
#  '15five',
#  '15minutesnow',
#  '15shopstop',
#  '16-mile-solutions',
#  '169-st',
#  '16lab-inc-',
#  '16wifi',
#  '17-media',
#  '170-systems',
#  '17hats',
#  '17hats',
#  '17u-cn',
#  '17u-cn',
#  '17u-cn',
#  '17zuoye',
#  '17zuoye',
#  '17zuoye',
#  '17zuoye',
#  '17zuoye',
#  '1800diapers',
#  '180solutions',
#  '1871',
#  '19pay',
#  '19pay',
#  '19pay',
#  '1bib',
#  '1bog',
#  '1c-company',
#  '1calendar',
#  '1cast',
#  '1click',
#  '1cloudstar-asia',
#  '1commmedical',
#  '1d4-pty',
#  '1day1song',
#  '1daylater',
#  '1daylater',
#  '1daymakeover',
#  '1doc3',
#  '1docway',
#  '1docway',
#  '1energy-systems',
#  '1eq',
#  '1eq',
#  '1eq',
#  '1jiajie',
#  '1jiajie',
#  '1lay',
#  '1lay',
#  '1life-healthcare',
#  '1mind',
#  '1mpact-revolution-powering-helpfreely-org',
#  '1mpact-revolution-powering-helpfreely-org',
#  '1mpact-revolution-powering-helpfreely-org',
#  '1mpact-revolution-powering-helpfreely-org',
#  '1mxians',
#  '1o1media',
#  '1rebel',
#  '1ring',
#  '1rp-media',
#  '1sdk',
#  '1sdk',
#  '1spire',
#  '1st-choice-lawn-care',
#  '1st-merchant-funding',
#  '1stdibs',
#  '1stdibs',
#  '1stdibs',
#  '1stdibs',
#  '1stdibs',
#  '1stgig-com',
#  '1v1-draft-gaems',
#  '1world-online',
#  '1world-online',
#  '1world-online',
#  '2-ladoshki',
#  '2-minutes',
#  '2-ngage-u',
#  '2-observe',
#  '2-pro-media-group',
#  '20-20-gene-systems-inc',
#  '20-20-gene-systems-inc',
#  '20-20-gene-systems-inc',
#  '20-20-mobile',
#  '2080-media',
#  '2080-media',
#  '2080-media',
#  '2080-media',
#  '2080-media',
#  '2080-media',
#  '2080-media',
#  '20lines',
#  '20lines',
#  '20lines',
#  '20n',
#  '20n',
#  '20x200',
#  '20x200',
#  '2100b-com-llc',
#  '2100b-com-llc',
#  '21cake-food-co',
#  '21diamonds-india',
#  '21e6',
#  '21e6',
#  '21grams',
#  '21st-century-oncology',
#  '21vianet',
#  '21vianet',
#  '21vianet',
#  '21vianet',
#  '21vianet',
#  '22nd-century-group',
#  '22nd-century-group',
#  '22nd-century-group',
#  '22nd-century-group',
#  '22nd-century-group',
#  '22nd-century-group',
#  '22seeds',
#  '2345-com',
#  '2345-com',
#  '2359-media',
#  '23andme',
#  '23andme',
#  '23andme',
#  '23andme',
#  '23andme',
#  '23andme',
#  '23andme',
#  '23andme',
#  '23press',
#  '24-7-card',
#  '24-7-card',
#  '24-7-card',
#  '24-7-customer',
#  '24-hour-pro-muscle-gym',
#  '24-media-network',
#  '24-media-network',
#  '24-quan',
#  '24-quan',
#  '247-learning-private',
#  '247-techies',
#  '248-solidstate',
#  '24fab',
#  '24fab',
#  '24fundraiser-com',
#  '24h00',
#  '24i',
#  '24m-technologies',
#  '24me',
#  '24med-sp',
#  '24pagebooks',
#  '24symbols',
#  '24symbols',
#  '24symbols',
#  '24tidy',
#  '24tidy',
#  '250ok',
#  '250ok',
#  '25eight',
#  '265-network',
#  '27-bards',
#  '27-perry',
#  '280-north',
#  '280-north',
#  '28msec',
#  '29west',
#  '2adpro-media-solutions',
#  '2b-angels',
#  '2c2p',
#  '2c2p',
#  '2c2p',
#  '2can',
#  '2can',
#  '2can',
#  '2catalyze',
#  '2checkout-com',
#  '2checkout-com',
#  '2code-online',
#  '2crisk',
#  '2crisk',
#  '2d2c',
#  '2d2c',
#  '2d2c',
#  '2degreesmobile',
#  '2dheat',
#  '2dheat',
#  '2dheat',
#  '2dheat',
#  '2duche',
#  '2duche',
#  '2go-software-solutions',
#  '2heuresavant',
#  '2houses',
#  '2houses',
#  '2lemetry',
#  '2mee',
#  '2morrow-mobile',
#  '2morrow-mobile',
#  '2nd-chance-solutions',
#  '2nd-screen-games',
#  '2nd-story-software-inc',
#  '2nd-watch',
#  '2nd-watch',
#  '2nd-watch',
#  '2nd-watch',
#  '2ndnature',
#  '2nite2nite-net',
#  '2pm-technologies',
#  '2redbeans',
#  '2sms',
#  '2theloo',
#  '2threads',
#  '2threads',
#  '2u',
#  '2u',
#  '2u',
#  '2u',
#  '2u',
#  '2u',
#  '2vancouver',
#  '2web-technologies',
#  '2win-solutions',
#  '2wire',
#  '2wire',
#  '2wire',
#  '2wire',
#  '2wire',
#  '3-day-blinds',
#  '3-four-5-group',
#  '3-kinds-of-ice',
#  '3-minute',
#  '3-v-biosciences',
#  '3-v-biosciences',
#  '3-v-biosciences',
#  '3-v-biosciences',
#  '3-v-biosciences',
#  '3-v-biosciences',
#  '3-v-biosciences',
#  '30-second-showcase',
#  '303-luxury-car-service',
#  '30secondstofly-claire',
#  '312-capital',
#  '31dover',
#  '321lend-inc',
#  '3225-films',
#  '33across',
#  '33across',
#  '33across',
#  '33across',
#  '33across',
#  '33coupons',
#  '360cities',
#  '360commerce',
#  '360commerce',
#  '360fly-inc',
#  '360guanxi',
#  '360imaging',
#  '360imaging',
#  '360incentives-com',
#  '360learning',
#  '360quan',
#  '360quan',
#  '360quan',
#  '360shop',
#  '360t',
#  '365-data-centers',
#  '365-docobites',
#  '365-good-teacher',
#  '365-retail-markets',
#  '365-retail-markets',
#  '365-retail-markets',
#  '365looks',
#  '365looks',
#  '365looks',
#  '365looks',
#  '365scores',
#  '365scores',
#  '365webcall',
#  '36kr',
#  '36kr',
#  '36kr',
#  '37coins',
#  '37coins',
#  '37mhealth',
#  '37signals',
#  '38-zeros',
#  '382-communications',
#  '39-health',
#  '39-health',
#  '3baysover',
#  '3baysover',
#  '3c-interactive',
#  '3c-plus',
#  '3ci',
#  '3claps-the-fastest-baby-fashion',
#  '3clickemr-corporation',
#  '3clickemr-corporation',
#  '3clogic',
#  '3clogic',
#  '3clogic',
#  '3clogic',
#  '3crowd-technologies',
#  '3crowd-technologies',
#  '3crowd-technologies',
#  '3d-4u',
#  '3d-biomatrix',
#  '3d-biomatrix',
#  '3d-by-flow',
#  '3d-control-systems',
#  '3d-data',
#  '3d-data',
#  '3d-eye-solutions',
#  '3d-eye-solutions',
#  '3d-forms',
#  '3d-future-vision-ii',
#  '3d-future-vision-ii',
#  '3d-heights',
#  '3d-hubs',
#  '3d-hubs',
#  '3d-industri-es',
#  '3d-industri-es',
#  '3d-intelligent-pathological-medical-image-solutions',
#  '3d-operations-inc',
#  '3d-product-imaging',
#  '3d-product-imaging',
#  '3d-robotics',
#  '3d-robotics',
#  '3d-robotics',
#  '3d-robotics',
#  '3d-simo-2',
#  '3d-sound-labs',
#  '3d-sports-technology',
#  '3d-sports-technology',
#  '3d-sports-technology',
#  '3d-systems',
#  '3d-systems',
#  '3d-systems',
#  '3d-vision-systems',
#  '3d4medical-com',
#  '3dbin',
#  '3dc',
#  '3dcart-shopping-cart-software',
#  '3dduo',
#  '3derm-systems',
#  '3derm-systems',
#  '3derm-systems',
#  '3derm-systems',
#  '3diligent',
#  '3diligent',
#  '3dim',
#  '3discovered',
#  '3divaz-2',
#  '3divaz-3',
#  '3divi-company',
#  '3divi-company',
#  '3dlt-com',
#  '3dmena',
#  '3dmgame',
#  '3dphotoworks',
#  '3dphy-com',
#  '3dplusme',
#  '3dplusme',
#  '3dplusme',
#  '3dprintus',
#  '3dr-laboratories',
#  '3dr-laboratories',
#  '3dshook-2',
#  '3dsoc',
#  '3dsoc',
#  '3dt',
#  '3dvista',
#  '3floz-com',
#  '3floz-com',
#  '3funnel',
#  '3g-multimedia',
#  '3g-multimedia',
#  '3gear-systems',
#  '3gear-systems',
#  '3guppies',
#  '3gv8-international-inc',
#  '3gv8-international-inc',
#  '3i-systems',
#  '3i-systems',
#  '3i-systems',
#  '3is',
#  '3jam',
#  '3keyit',
#  '3leaf',
#  '3leaf',
#  '3leaf',
#  '3lm',
#  '3nder',
#  '3nder',
#  '3p-biopharmaceuticals',
#  '3p-biopharmaceuticals',
#  '3par',
#  '3par',
#  '3par',
#  '3pillar-global',
#  '3pillar-global',
#  '3pillar-global',
#  '3pillar-global',
#  '3pl-central',
#  '3play-media',
#  '3play-media',
#  '3play-media',
#  '3point5-com',
#  '3pointdata',
#  '3power-energy-group',
#  '3rd-planet',
#  '3rd-planet',
#  '3rdkind',
#  '3roam',
#  '3scale',
#  '3scale',
#  '3scan',
#  '3scan',
#  '3scan',
#  '3scan',
#  '3seventy',
#  '3si-security-systems',
#  '3sourcing',
#  '3sourcing',
#  '3sp-group',
#  '3sun',
#  '3ten8',
#  '3tier-environmental-forecast-group',
#  '3tier-environmental-forecast-group',
#  '3tier-environmental-forecast-group',
#  '3touch',
#  '3v-transaction-services',
#  '3v-transaction-services',
#  '3vr-security',
#  '3vr-security',
#  '3vr-security',
#  '3vr-security',
#  '3vr-security',
#  '3vr-security',
#  '3vr-security',
#  '3ware',
#  '3x-systems',
#  '3x-systems',
#  '3yy-game-platform',
#  '4-33-creative-lab',
#  '4-animals-alsterscience-gmbh',
#  '4-antibody-ag',
#  '4-cast-broadcasting-corporation',
#  '4-tell',
#  '4-tell',
#  '4-tell',
#  '4-tell',
#  '4-tell',
#  '4-tell',
#  '4-the-stars',
#  '40-partners-ltd',
#  '404-found',
#  '404-found',
#  '405labs',
#  '40billion-com',
#  '40billion-com',
#  '40billion-com',
#  '410-labs',
#  '41st-parameter',
#  '41st-parameter',
#  '41st-parameter',
#  '41st-parameter',
#  '42',
#  '42',
#  '422-group',
#  '425-307-3480',
#  '42floors',
#  '42floors',
#  '42floors',
#  '42floors',
#  '42matters-ag',
#  '42matters-ag',
#  '42networks',
#  '42race',
#  '43things',
#  '447-461-broadway-partners',
#  '44lab5',
#  '46elks',
#  '46elks',
#  '480-biomedical',
#  '480-biomedical',
#  '480-biomedical',
#  '480-biomedical',
#  '480-biomedical',
#  '48domain',
#  '490-entertainment',
#  '4blox',
#  '4c-insights',
#  '4cable-tv',
#  '4d-energetics',
#  '4d-energetics',
#  '4d-molecular-therapeutics',
#  '4deep',
#  '4dk-technologies',
#  '4energy',
#  '4front-partners',
#  '4front-security',
#  '4home',
#  '4home',
#  '4home',
#  '4home',
#  '4home',
#  '4home',
#  '4info',
#  '4info',
#  '4info',
#  '4info',
#  '4info',
#  '4info',
#  '4info',
#  '4info',
#  '4less',
#  '4med-centra-medyczne',
#  '4meee',
#  '4moms',
#  '4moms',
#  '4moms',
#  '4moms',
#  '4moms',
#  '4plat',
#  '4psa',
#  '4psa',
#  '4psa',
#  '4runners-entertainment',
#  '4s91-com',
#  '4sc',
#  '4scotty-gmbh',
#  '4screens',
#  '4soils',
#  '4tech',
#  '4tell-solutions',
#  '4th-aspect',
#  '4th-aspect',
#  '4th-aspect',
#  '4th-aspect',
#  '4th-office',
#  '4thetable',
#  '4tiitoo',
#  '4tiitoo',
#  '4tiitoo',
#  '4urspace',
#  '4vets',
#  '4wave',
#  '4x4-aviation',
#  '5-cups-and-some-sugar',
#  '5-examples',
#  '5-million-shoppers',
#  '5-minutes',
#  '5-oclock-records',
#  '5-oclock-records',
#  '5-screens-media',
#  '5-screens-media',
#  '5-star-mobile',
#  '5-star-quarterback',
#  '5-stars-vacation-rentals',
#  '50-cubes',
#  '50-partners',
#  '500-luchadores',
#  '500friends',
#  '500friends',
#  '500friends',
#  '500friends',
#  '500friends',
#  '500friends',
#  '500indies',
#  '500px',
#  '500px',
#  '500px',
#  '500px',
#  '500px',
#  '500px',
#  '500px',
#  '500shops',
#  '51-auto',
#  '51-com',
#  '51-com',
#  '51-com',
#  '51-give',
#  '51-qiangzuo',
#  '5151tuan',
#  '5173-com',
#  '5173-com',
#  '5173-com',
#  '51credit-com',
#  '51credit-com',
#  '51cto',
#  '51edj',
#  '51edj',
#  '51edu',
#  '51edu',
#  '51hejia-com',
#  '51intern-com-2',
#  '51talk',
#  '51talk',
#  '51talk',
#  '51talk',
#  '51tour',
#  '51wan',
#  '51wan',
#  '51wofang-æ—\xa0å¿§æˆ‘æˆ¿',
#  '51yongche',
#  '51zhangdan',
#  '51zhangdan',
#  '51zhangdan',
#  '5211game',
#  '525j-com-cn',
#  '52masterworks',
#  '52masterworks',
#  '52masterworks',
#  '556-fitness',
#  '55social',
#  '55tuan-com',
#  '55tuan-com',
#  '56-com',
#  '56-com',
#  '58-com',
#  '58-com',
#  '58-com',
#  '58-com',
#  '58-com',
#  '58-com',
#  '58daojia',
#  '591wed',
#  '59saniye',
#  '59sec-2',
#  '5app',
#  '5barz-international',
#  '5barz-international',
#  '5by',
#  '5dpnp',
#  '5ensesinfood',
#  '5gig',
#  '5i-sciences',
#  '5i-sciences',
#  '5k-fans',
#  '5m-ventures',
#  '5min',
#  '5min',
#  '5min',
#  '5minutes',
#  '5nine-software',
#  '5o9',
#  '5rocks',
#  '5rocks',
#  '5skills',
#  '5th-avenue-media',
#  '5th-finger',
#  '5th-planet-games',
#  '5to1',
#  '5to1',
#  '5to1',
#  '5to1',
#  '60frames-entertainment',
#  '60mo',
#  '60mo',
#  '60mo',
#  '64-pixels',
#  '640-labs',
#  '640-labs',
#  '640-labs',
#  '66-com',
#  '6apt',
#  '6connect',
#  '6connect',
#  '6cube',
#  '6d-global-technologies',
#  '6d-global-technologies',
#  '6degrees',
#  '6ep',
#  '6fusion',
#  '6fusion',
#  '6fusion',
#  '6fusion',
#  '6fusion',
#  '6n-silicon',
#  '6px',
#  '6renyou-com',
#  '6renyou-com',
#  '6rooms',
#  '6rooms',
#  '6rooms',
#  '6scan',
#  '6scan',
#  '6scan',
#  '6sense',
#  '6sense',
#  '6sense',
#  '6sensor-labs',
#  '6sensor-labs',
#  '6sicuro-it',
#  '6th-sense-analytics',
#  '6th-sense-analytics',
#  '6th-wave-innovations-corporation',
#  '6th-wave-innovations-corporation',
#  '6tribes',
#  '6tribes',
#  '6tribes',
#  '6wunderkinder',
#  '6wunderkinder',
#  '6wunderkinder',
#  '6wunderkinder',
#  '6wunderkinder',
#  '7-billion-people',
#  '7-billion-people',
#  '7-billion-people',
#  '7-bites',
#  '7-cups-of-tea',
#  '7-cups-of-tea',
#  '7-elements-studios',
#  '7-oaks-pharmaceutical',
#  '7-star-entertainment',
#  '700bike',
#  '71lbs',
#  '71lbs',
#  '71lbs',
#  '71lbs',
#  '71lbs',
#  '720',
#  '72798-com',
#  '72lux',
#  '72lux',
#  '72xuan',
#  '77-pieces',
#  '777-davis',
#  '79-group',
#  '7ac-technologies',
#  '7ac-technologies',
#  '7ac-technologies',
#  '7ac-technologies',
#  '7ac-technologies',
#  '7ac-technologies',
#  '7billionideas',
#  '7digital',
#  '7digital',
#  '7digital',
#  '7digital',
#  '7dnei-net',
#  '7fgame',
#  '7k7k-com',
#  '7k7k-com',
#  '7mb-technologies',
#  '7mb-technologies',
#  '7mb-technologies',
#  '7park-data',
#  '7signal-solutions',
#  '7signal-solutions',
#  '7signal-solutions',
#  '7signal-solutions',
#  '7summits',
#  '7summits',
#  '7summits',
#  '7tm-pharma',
#  '7write',
#  '7write',
#  '8-50-sports',
#  '8-inc',
#  '8-inc',
#  '8-securities-limited',
#  '8-securities-limited',
#  '80-20-solutions',
#  '80-degrees-west',
#  '80-degrees-west',
#  '800-com',
#  '800-com',
#  '800app',
#  '800app',
#  '800razors',
#  '8020publishing',
#  '8020select',
#  '8020select',
#  '8020select',
#  '80th-street-residence-facc-fund-i',
#  '818-sports-entertainment',
#  '818-sports-entertainment',
#  '8218-west-third',
#  '88-famibio',
#  '8868',
#  '88tc88',
#  '89-bits-entertainment-studio',
#  '8aweek',
#  '8bit-2',
#  '8bit-2',
#  '8digits',
#  '8digits',
#  '8dworld',
#  '8dworld',
#  '8eighty-wear',
#  '8fit-fitness-for-the-rest-of-us',
#  '8fit-fitness-for-the-rest-of-us',
#  '8fit-fitness-for-the-rest-of-us',
#  '8hands',
#  '8hands',
#  '8i',
#  '8i',
#  '8minutenergy-renewables',
#  '8packs',
#  '8packs',
#  '8th-story',
#  '8tracks',
#  '8tracks',
#  '8tracks',
#  '8trip',
#  '8villages',
#  '8wood',
#  '8x8-inc',
#  '9-plus-studio',
#  '9-plus-studio',
#  '908-devices',
#  '908-devices',
#  '908-devices',
#  '908-devices',
#  '909c',
#  '90min',
#  '90min',
#  '90min',
#  '90sec-technologies',
#  '91-boyuan-wireles',
#  '91-golf',
#  '91-wireless',
#  '911-pets',
#  '911-view',
#  '915-labs-llc',
#  '915-labs-llc',
#  '9158-julur-com',
#  '91app',
#  '91datong-com',
#  '91jinrong',
#  '91jinrong',
#  '91jinrong',
#  '91mobiles',
#  '955-dreams',
#  '955-dreams',
#  '955-dreams',
#  '99-co',
#  '99-co',
#  '99-fahrenheit',
#  '99bill',
#  '99bill',
#  '99bill',
#  '99bill',
#  '99bill',
#  '99chairs',
#  '99cloud',
#  '99degrees-custom',
#  '99degrees-custom',
#  '99designs',
#  '99designs',
#  '99dresses',
#  '99dresses',
#  '99drones',
#  '99gamers',
#  '99games-online-private-limited',
#  '99inn-cc',
#  '99jobs',
#  '99motos',
#  '99presents',
#  '99taojin-com',
#  '99taxis',
#  '99taxis',
#  '99taxis',
#  '99tests',
#  '99tests',
#  '99tests',
#  '99times-cn',
#  '9car-technology-llc',
#  '9car-technology-llc',
#  '9cookies',
#  '9diamond',
#  '9diamond',
#  '9facts',
#  ...]

# %%
rounds2['companyname']=companyname
rounds2.head(2)
# Out:
#         company_permalink                          funding_round_permalink  \
# 0     /organization/-fame  /funding-round/9a01d05418af9f794eebff7ace91f638
# 1  /ORGANIZATION/-QOUNTER  /funding-round/22dacff496eb7acb2b901dec1dfe5633
#
#   funding_round_type funding_round_code   funded_at  raised_amount_usd  \
# 0            venture                  B  05-01-2015         10000000.0
# 1            venture                  A  14-10-2014                NaN
#
#   companyname
# 0       -fame
# 1    -qounter

# %%
companyname=[]
for i in rounds2['companyname']:
    companyname.append(i.replace('-',''))
companyname
# Out:
# ['fame',
#  'qounter',
#  'qounter',
#  'theoneoftheminc',
#  '06com',
#  '004technologies',
#  '01gamestechnology',
#  '0ndinebiomedicalinc',
#  '0ndinebiomedicalinc',
#  '0xdata',
#  '0xdata',
#  '0xdata',
#  '0xdata',
#  '1',
#  '1',
#  '1',
#  '123listo',
#  '14all',
#  '1618technology',
#  '1800dentist',
#  '1800doctors',
#  '1800publicrelationsinc',
#  '1mainstream',
#  '1of99',
#  '1020media',
#  '1020media',
#  '1020media',
#  '1020media',
#  '10minuteswith',
#  '10minuteswith',
#  '1000corks',
#  '1000markets',
#  '1000chi',
#  '1000lookz',
#  '1000memories',
#  '1000memories',
#  '1000museumscom',
#  '1000museumscom',
#  '1000museumscom',
#  '1000museumscom',
#  '1000museumscom',
#  '1000museumscom',
#  '1000museumscom',
#  '1000museumscom',
#  '1000museumscom',
#  '1001menus',
#  '1001menus',
#  '1001menus',
#  '1001menus',
#  '1001menus',
#  '1001pharmaciescom',
#  '1006tv',
#  '1006tv',
#  '1006tv',
#  '100dutv',
#  '100dutv',
#  '100ecom',
#  '100ecom',
#  '100health',
#  '100health',
#  '100plus',
#  '100plus',
#  '1010data',
#  '10alike',
#  '10alike',
#  '10bestthings',
#  '10k2',
#  '10sec',
#  '10sec',
#  '10secondssoftware',
#  '10six',
#  '10tracks2',
#  '10tracks2',
#  '10xgenomics',
#  '10xtechnologies',
#  '10xtechnologies',
#  '10x10room',
#  '10â°north',
#  '11health',
#  '115networkdisks',
#  '117go',
#  '11isolutions',
#  '12labs',
#  '12starsurvival',
#  '120sports',
#  '121rentals',
#  '121cast',
#  '121cast',
#  '121cast',
#  '121nexus',
#  '121nexus',
#  '121nexus',
#  '121nexus',
#  '121nexus',
#  '121nexus',
#  '1234enter',
#  '1234enter',
#  '123contactform',
#  '123contactform',
#  '123fengcom',
#  '123greetings',
#  '123people',
#  '1248',
#  '128technology',
#  '12bis',
#  '12cm',
#  '12return',
#  '12society',
#  '1366technologies',
#  '1366technologies',
#  '1366technologies',
#  '1366technologies',
#  '1366technologies',
#  '1366technologies',
#  '1366technologies',
#  '1366technologies',
#  '1366technologies',
#  '139shop',
#  '13thlab',
#  '140proof',
#  '140proof',
#  '140fire',
#  '1417',
#  '15fen',
#  '15five',
#  '15five',
#  '15five',
#  '15minutesnow',
#  '15shopstop',
#  '16milesolutions',
#  '169st',
#  '16labinc',
#  '16wifi',
#  '17media',
#  '170systems',
#  '17hats',
#  '17hats',
#  '17ucn',
#  '17ucn',
#  '17ucn',
#  '17zuoye',
#  '17zuoye',
#  '17zuoye',
#  '17zuoye',
#  '17zuoye',
#  '1800diapers',
#  '180solutions',
#  '1871',
#  '19pay',
#  '19pay',
#  '19pay',
#  '1bib',
#  '1bog',
#  '1ccompany',
#  '1calendar',
#  '1cast',
#  '1click',
#  '1cloudstarasia',
#  '1commmedical',
#  '1d4pty',
#  '1day1song',
#  '1daylater',
#  '1daylater',
#  '1daymakeover',
#  '1doc3',
#  '1docway',
#  '1docway',
#  '1energysystems',
#  '1eq',
#  '1eq',
#  '1eq',
#  '1jiajie',
#  '1jiajie',
#  '1lay',
#  '1lay',
#  '1lifehealthcare',
#  '1mind',
#  '1mpactrevolutionpoweringhelpfreelyorg',
#  '1mpactrevolutionpoweringhelpfreelyorg',
#  '1mpactrevolutionpoweringhelpfreelyorg',
#  '1mpactrevolutionpoweringhelpfreelyorg',
#  '1mxians',
#  '1o1media',
#  '1rebel',
#  '1ring',
#  '1rpmedia',
#  '1sdk',
#  '1sdk',
#  '1spire',
#  '1stchoicelawncare',
#  '1stmerchantfunding',
#  '1stdibs',
#  '1stdibs',
#  '1stdibs',
#  '1stdibs',
#  '1stdibs',
#  '1stgigcom',
#  '1v1draftgaems',
#  '1worldonline',
#  '1worldonline',
#  '1worldonline',
#  '2ladoshki',
#  '2minutes',
#  '2ngageu',
#  '2observe',
#  '2promediagroup',
#  '2020genesystemsinc',
#  '2020genesystemsinc',
#  '2020genesystemsinc',
#  '2020mobile',
#  '2080media',
#  '2080media',
#  '2080media',
#  '2080media',
#  '2080media',
#  '2080media',
#  '2080media',
#  '20lines',
#  '20lines',
#  '20lines',
#  '20n',
#  '20n',
#  '20x200',
#  '20x200',
#  '2100bcomllc',
#  '2100bcomllc',
#  '21cakefoodco',
#  '21diamondsindia',
#  '21e6',
#  '21e6',
#  '21grams',
#  '21stcenturyoncology',
#  '21vianet',
#  '21vianet',
#  '21vianet',
#  '21vianet',
#  '21vianet',
#  '22ndcenturygroup',
#  '22ndcenturygroup',
#  '22ndcenturygroup',
#  '22ndcenturygroup',
#  '22ndcenturygroup',
#  '22ndcenturygroup',
#  '22seeds',
#  '2345com',
#  '2345com',
#  '2359media',
#  '23andme',
#  '23andme',
#  '23andme',
#  '23andme',
#  '23andme',
#  '23andme',
#  '23andme',
#  '23andme',
#  '23press',
#  '247card',
#  '247card',
#  '247card',
#  '247customer',
#  '24hourpromusclegym',
#  '24medianetwork',
#  '24medianetwork',
#  '24quan',
#  '24quan',
#  '247learningprivate',
#  '247techies',
#  '248solidstate',
#  '24fab',
#  '24fab',
#  '24fundraisercom',
#  '24h00',
#  '24i',
#  '24mtechnologies',
#  '24me',
#  '24medsp',
#  '24pagebooks',
#  '24symbols',
#  '24symbols',
#  '24symbols',
#  '24tidy',
#  '24tidy',
#  '250ok',
#  '250ok',
#  '25eight',
#  '265network',
#  '27bards',
#  '27perry',
#  '280north',
#  '280north',
#  '28msec',
#  '29west',
#  '2adpromediasolutions',
#  '2bangels',
#  '2c2p',
#  '2c2p',
#  '2c2p',
#  '2can',
#  '2can',
#  '2can',
#  '2catalyze',
#  '2checkoutcom',
#  '2checkoutcom',
#  '2codeonline',
#  '2crisk',
#  '2crisk',
#  '2d2c',
#  '2d2c',
#  '2d2c',
#  '2degreesmobile',
#  '2dheat',
#  '2dheat',
#  '2dheat',
#  '2dheat',
#  '2duche',
#  '2duche',
#  '2gosoftwaresolutions',
#  '2heuresavant',
#  '2houses',
#  '2houses',
#  '2lemetry',
#  '2mee',
#  '2morrowmobile',
#  '2morrowmobile',
#  '2ndchancesolutions',
#  '2ndscreengames',
#  '2ndstorysoftwareinc',
#  '2ndwatch',
#  '2ndwatch',
#  '2ndwatch',
#  '2ndwatch',
#  '2ndnature',
#  '2nite2nitenet',
#  '2pmtechnologies',
#  '2redbeans',
#  '2sms',
#  '2theloo',
#  '2threads',
#  '2threads',
#  '2u',
#  '2u',
#  '2u',
#  '2u',
#  '2u',
#  '2u',
#  '2vancouver',
#  '2webtechnologies',
#  '2winsolutions',
#  '2wire',
#  '2wire',
#  '2wire',
#  '2wire',
#  '2wire',
#  '3dayblinds',
#  '3four5group',
#  '3kindsofice',
#  '3minute',
#  '3vbiosciences',
#  '3vbiosciences',
#  '3vbiosciences',
#  '3vbiosciences',
#  '3vbiosciences',
#  '3vbiosciences',
#  '3vbiosciences',
#  '30secondshowcase',
#  '303luxurycarservice',
#  '30secondstoflyclaire',
#  '312capital',
#  '31dover',
#  '321lendinc',
#  '3225films',
#  '33across',
#  '33across',
#  '33across',
#  '33across',
#  '33across',
#  '33coupons',
#  '360cities',
#  '360commerce',
#  '360commerce',
#  '360flyinc',
#  '360guanxi',
#  '360imaging',
#  '360imaging',
#  '360incentivescom',
#  '360learning',
#  '360quan',
#  '360quan',
#  '360quan',
#  '360shop',
#  '360t',
#  '365datacenters',
#  '365docobites',
#  '365goodteacher',
#  '365retailmarkets',
#  '365retailmarkets',
#  '365retailmarkets',
#  '365looks',
#  '365looks',
#  '365looks',
#  '365looks',
#  '365scores',
#  '365scores',
#  '365webcall',
#  '36kr',
#  '36kr',
#  '36kr',
#  '37coins',
#  '37coins',
#  '37mhealth',
#  '37signals',
#  '38zeros',
#  '382communications',
#  '39health',
#  '39health',
#  '3baysover',
#  '3baysover',
#  '3cinteractive',
#  '3cplus',
#  '3ci',
#  '3clapsthefastestbabyfashion',
#  '3clickemrcorporation',
#  '3clickemrcorporation',
#  '3clogic',
#  '3clogic',
#  '3clogic',
#  '3clogic',
#  '3crowdtechnologies',
#  '3crowdtechnologies',
#  '3crowdtechnologies',
#  '3d4u',
#  '3dbiomatrix',
#  '3dbiomatrix',
#  '3dbyflow',
#  '3dcontrolsystems',
#  '3ddata',
#  '3ddata',
#  '3deyesolutions',
#  '3deyesolutions',
#  '3dforms',
#  '3dfuturevisionii',
#  '3dfuturevisionii',
#  '3dheights',
#  '3dhubs',
#  '3dhubs',
#  '3dindustries',
#  '3dindustries',
#  '3dintelligentpathologicalmedicalimagesolutions',
#  '3doperationsinc',
#  '3dproductimaging',
#  '3dproductimaging',
#  '3drobotics',
#  '3drobotics',
#  '3drobotics',
#  '3drobotics',
#  '3dsimo2',
#  '3dsoundlabs',
#  '3dsportstechnology',
#  '3dsportstechnology',
#  '3dsportstechnology',
#  '3dsystems',
#  '3dsystems',
#  '3dsystems',
#  '3dvisionsystems',
#  '3d4medicalcom',
#  '3dbin',
#  '3dc',
#  '3dcartshoppingcartsoftware',
#  '3dduo',
#  '3dermsystems',
#  '3dermsystems',
#  '3dermsystems',
#  '3dermsystems',
#  '3diligent',
#  '3diligent',
#  '3dim',
#  '3discovered',
#  '3divaz2',
#  '3divaz3',
#  '3divicompany',
#  '3divicompany',
#  '3dltcom',
#  '3dmena',
#  '3dmgame',
#  '3dphotoworks',
#  '3dphycom',
#  '3dplusme',
#  '3dplusme',
#  '3dplusme',
#  '3dprintus',
#  '3drlaboratories',
#  '3drlaboratories',
#  '3dshook2',
#  '3dsoc',
#  '3dsoc',
#  '3dt',
#  '3dvista',
#  '3flozcom',
#  '3flozcom',
#  '3funnel',
#  '3gmultimedia',
#  '3gmultimedia',
#  '3gearsystems',
#  '3gearsystems',
#  '3guppies',
#  '3gv8internationalinc',
#  '3gv8internationalinc',
#  '3isystems',
#  '3isystems',
#  '3isystems',
#  '3is',
#  '3jam',
#  '3keyit',
#  '3leaf',
#  '3leaf',
#  '3leaf',
#  '3lm',
#  '3nder',
#  '3nder',
#  '3pbiopharmaceuticals',
#  '3pbiopharmaceuticals',
#  '3par',
#  '3par',
#  '3par',
#  '3pillarglobal',
#  '3pillarglobal',
#  '3pillarglobal',
#  '3pillarglobal',
#  '3plcentral',
#  '3playmedia',
#  '3playmedia',
#  '3playmedia',
#  '3point5com',
#  '3pointdata',
#  '3powerenergygroup',
#  '3rdplanet',
#  '3rdplanet',
#  '3rdkind',
#  '3roam',
#  '3scale',
#  '3scale',
#  '3scan',
#  '3scan',
#  '3scan',
#  '3scan',
#  '3seventy',
#  '3sisecuritysystems',
#  '3sourcing',
#  '3sourcing',
#  '3spgroup',
#  '3sun',
#  '3ten8',
#  '3tierenvironmentalforecastgroup',
#  '3tierenvironmentalforecastgroup',
#  '3tierenvironmentalforecastgroup',
#  '3touch',
#  '3vtransactionservices',
#  '3vtransactionservices',
#  '3vrsecurity',
#  '3vrsecurity',
#  '3vrsecurity',
#  '3vrsecurity',
#  '3vrsecurity',
#  '3vrsecurity',
#  '3vrsecurity',
#  '3ware',
#  '3xsystems',
#  '3xsystems',
#  '3yygameplatform',
#  '433creativelab',
#  '4animalsalstersciencegmbh',
#  '4antibodyag',
#  '4castbroadcastingcorporation',
#  '4tell',
#  '4tell',
#  '4tell',
#  '4tell',
#  '4tell',
#  '4tell',
#  '4thestars',
#  '40partnersltd',
#  '404found',
#  '404found',
#  '405labs',
#  '40billioncom',
#  '40billioncom',
#  '40billioncom',
#  '410labs',
#  '41stparameter',
#  '41stparameter',
#  '41stparameter',
#  '41stparameter',
#  '42',
#  '42',
#  '422group',
#  '4253073480',
#  '42floors',
#  '42floors',
#  '42floors',
#  '42floors',
#  '42mattersag',
#  '42mattersag',
#  '42networks',
#  '42race',
#  '43things',
#  '447461broadwaypartners',
#  '44lab5',
#  '46elks',
#  '46elks',
#  '480biomedical',
#  '480biomedical',
#  '480biomedical',
#  '480biomedical',
#  '480biomedical',
#  '48domain',
#  '490entertainment',
#  '4blox',
#  '4cinsights',
#  '4cabletv',
#  '4denergetics',
#  '4denergetics',
#  '4dmoleculartherapeutics',
#  '4deep',
#  '4dktechnologies',
#  '4energy',
#  '4frontpartners',
#  '4frontsecurity',
#  '4home',
#  '4home',
#  '4home',
#  '4home',
#  '4home',
#  '4home',
#  '4info',
#  '4info',
#  '4info',
#  '4info',
#  '4info',
#  '4info',
#  '4info',
#  '4info',
#  '4less',
#  '4medcentramedyczne',
#  '4meee',
#  '4moms',
#  '4moms',
#  '4moms',
#  '4moms',
#  '4moms',
#  '4plat',
#  '4psa',
#  '4psa',
#  '4psa',
#  '4runnersentertainment',
#  '4s91com',
#  '4sc',
#  '4scottygmbh',
#  '4screens',
#  '4soils',
#  '4tech',
#  '4tellsolutions',
#  '4thaspect',
#  '4thaspect',
#  '4thaspect',
#  '4thaspect',
#  '4thoffice',
#  '4thetable',
#  '4tiitoo',
#  '4tiitoo',
#  '4tiitoo',
#  '4urspace',
#  '4vets',
#  '4wave',
#  '4x4aviation',
#  '5cupsandsomesugar',
#  '5examples',
#  '5millionshoppers',
#  '5minutes',
#  '5oclockrecords',
#  '5oclockrecords',
#  '5screensmedia',
#  '5screensmedia',
#  '5starmobile',
#  '5starquarterback',
#  '5starsvacationrentals',
#  '50cubes',
#  '50partners',
#  '500luchadores',
#  '500friends',
#  '500friends',
#  '500friends',
#  '500friends',
#  '500friends',
#  '500friends',
#  '500indies',
#  '500px',
#  '500px',
#  '500px',
#  '500px',
#  '500px',
#  '500px',
#  '500px',
#  '500shops',
#  '51auto',
#  '51com',
#  '51com',
#  '51com',
#  '51give',
#  '51qiangzuo',
#  '5151tuan',
#  '5173com',
#  '5173com',
#  '5173com',
#  '51creditcom',
#  '51creditcom',
#  '51cto',
#  '51edj',
#  '51edj',
#  '51edu',
#  '51edu',
#  '51hejiacom',
#  '51interncom2',
#  '51talk',
#  '51talk',
#  '51talk',
#  '51talk',
#  '51tour',
#  '51wan',
#  '51wan',
#  '51wofangæ—\xa0å¿§æˆ‘æˆ¿',
#  '51yongche',
#  '51zhangdan',
#  '51zhangdan',
#  '51zhangdan',
#  '5211game',
#  '525jcomcn',
#  '52masterworks',
#  '52masterworks',
#  '52masterworks',
#  '556fitness',
#  '55social',
#  '55tuancom',
#  '55tuancom',
#  '56com',
#  '56com',
#  '58com',
#  '58com',
#  '58com',
#  '58com',
#  '58com',
#  '58com',
#  '58daojia',
#  '591wed',
#  '59saniye',
#  '59sec2',
#  '5app',
#  '5barzinternational',
#  '5barzinternational',
#  '5by',
#  '5dpnp',
#  '5ensesinfood',
#  '5gig',
#  '5isciences',
#  '5isciences',
#  '5kfans',
#  '5mventures',
#  '5min',
#  '5min',
#  '5min',
#  '5minutes',
#  '5ninesoftware',
#  '5o9',
#  '5rocks',
#  '5rocks',
#  '5skills',
#  '5thavenuemedia',
#  '5thfinger',
#  '5thplanetgames',
#  '5to1',
#  '5to1',
#  '5to1',
#  '5to1',
#  '60framesentertainment',
#  '60mo',
#  '60mo',
#  '60mo',
#  '64pixels',
#  '640labs',
#  '640labs',
#  '640labs',
#  '66com',
#  '6apt',
#  '6connect',
#  '6connect',
#  '6cube',
#  '6dglobaltechnologies',
#  '6dglobaltechnologies',
#  '6degrees',
#  '6ep',
#  '6fusion',
#  '6fusion',
#  '6fusion',
#  '6fusion',
#  '6fusion',
#  '6nsilicon',
#  '6px',
#  '6renyoucom',
#  '6renyoucom',
#  '6rooms',
#  '6rooms',
#  '6rooms',
#  '6scan',
#  '6scan',
#  '6scan',
#  '6sense',
#  '6sense',
#  '6sense',
#  '6sensorlabs',
#  '6sensorlabs',
#  '6sicuroit',
#  '6thsenseanalytics',
#  '6thsenseanalytics',
#  '6thwaveinnovationscorporation',
#  '6thwaveinnovationscorporation',
#  '6tribes',
#  '6tribes',
#  '6tribes',
#  '6wunderkinder',
#  '6wunderkinder',
#  '6wunderkinder',
#  '6wunderkinder',
#  '6wunderkinder',
#  '7billionpeople',
#  '7billionpeople',
#  '7billionpeople',
#  '7bites',
#  '7cupsoftea',
#  '7cupsoftea',
#  '7elementsstudios',
#  '7oakspharmaceutical',
#  '7starentertainment',
#  '700bike',
#  '71lbs',
#  '71lbs',
#  '71lbs',
#  '71lbs',
#  '71lbs',
#  '720',
#  '72798com',
#  '72lux',
#  '72lux',
#  '72xuan',
#  '77pieces',
#  '777davis',
#  '79group',
#  '7actechnologies',
#  '7actechnologies',
#  '7actechnologies',
#  '7actechnologies',
#  '7actechnologies',
#  '7actechnologies',
#  '7billionideas',
#  '7digital',
#  '7digital',
#  '7digital',
#  '7digital',
#  '7dneinet',
#  '7fgame',
#  '7k7kcom',
#  '7k7kcom',
#  '7mbtechnologies',
#  '7mbtechnologies',
#  '7mbtechnologies',
#  '7parkdata',
#  '7signalsolutions',
#  '7signalsolutions',
#  '7signalsolutions',
#  '7signalsolutions',
#  '7summits',
#  '7summits',
#  '7summits',
#  '7tmpharma',
#  '7write',
#  '7write',
#  '850sports',
#  '8inc',
#  '8inc',
#  '8securitieslimited',
#  '8securitieslimited',
#  '8020solutions',
#  '80degreeswest',
#  '80degreeswest',
#  '800com',
#  '800com',
#  '800app',
#  '800app',
#  '800razors',
#  '8020publishing',
#  '8020select',
#  '8020select',
#  '8020select',
#  '80thstreetresidencefaccfundi',
#  '818sportsentertainment',
#  '818sportsentertainment',
#  '8218westthird',
#  '88famibio',
#  '8868',
#  '88tc88',
#  '89bitsentertainmentstudio',
#  '8aweek',
#  '8bit2',
#  '8bit2',
#  '8digits',
#  '8digits',
#  '8dworld',
#  '8dworld',
#  '8eightywear',
#  '8fitfitnessfortherestofus',
#  '8fitfitnessfortherestofus',
#  '8fitfitnessfortherestofus',
#  '8hands',
#  '8hands',
#  '8i',
#  '8i',
#  '8minutenergyrenewables',
#  '8packs',
#  '8packs',
#  '8thstory',
#  '8tracks',
#  '8tracks',
#  '8tracks',
#  '8trip',
#  '8villages',
#  '8wood',
#  '8x8inc',
#  '9plusstudio',
#  '9plusstudio',
#  '908devices',
#  '908devices',
#  '908devices',
#  '908devices',
#  '909c',
#  '90min',
#  '90min',
#  '90min',
#  '90sectechnologies',
#  '91boyuanwireles',
#  '91golf',
#  '91wireless',
#  '911pets',
#  '911view',
#  '915labsllc',
#  '915labsllc',
#  '9158julurcom',
#  '91app',
#  '91datongcom',
#  '91jinrong',
#  '91jinrong',
#  '91jinrong',
#  '91mobiles',
#  '955dreams',
#  '955dreams',
#  '955dreams',
#  '99co',
#  '99co',
#  '99fahrenheit',
#  '99bill',
#  '99bill',
#  '99bill',
#  '99bill',
#  '99bill',
#  '99chairs',
#  '99cloud',
#  '99degreescustom',
#  '99degreescustom',
#  '99designs',
#  '99designs',
#  '99dresses',
#  '99dresses',
#  '99drones',
#  '99gamers',
#  '99gamesonlineprivatelimited',
#  '99inncc',
#  '99jobs',
#  '99motos',
#  '99presents',
#  '99taojincom',
#  '99taxis',
#  '99taxis',
#  '99taxis',
#  '99tests',
#  '99tests',
#  '99tests',
#  '99timescn',
#  '9cartechnologyllc',
#  '9cartechnologyllc',
#  '9cookies',
#  '9diamond',
#  '9diamond',
#  '9facts',
#  ...]

# %%
rounds2['companyname']=companyname
rounds2.head(2)
# Out:
#         company_permalink                          funding_round_permalink  \
# 0     /organization/-fame  /funding-round/9a01d05418af9f794eebff7ace91f638
# 1  /ORGANIZATION/-QOUNTER  /funding-round/22dacff496eb7acb2b901dec1dfe5633
#
#   funding_round_type funding_round_code   funded_at  raised_amount_usd  \
# 0            venture                  B  05-01-2015         10000000.0
# 1            venture                  A  14-10-2014                NaN
#
#   companyname
# 0        fame
# 1     qounter

# %%
rounds2['companyname'].unique()
# Out:
# array(['fame', 'qounter', 'theoneoftheminc', ..., 'ã\x81eron', 'ã”asys2',
#        'ä°novatiffreklamvetanä±tä±mhizmetleritic'], dtype=object)

# %%
rounds2['companyname'].nunique()
# Out:
# 66290

# %% [markdown]
# 3.In the companies data frame, which column can be used as the unique key for each company? Write the name of the column.
# Ans.'permalink'

# %% [markdown]
# 4.Are there any companies in the rounds2 file which are not present in
# companies?
# Ans:No

# %% [markdown]
# since the difference is zero,the companies present in both the files are same

# %%
#4.Merge the two data frames so that all variables (columns) in the companies frame are added to the rounds2 data frame. Name the merged frame master_frame. How many observations are present in master_frame?
master_frame=pd.merge(left=companies,right=rounds2,on='companyname')
master_frame.head(2)
# Out:
#                 permalink      name            homepage_url  \
# 0     /Organization/-Fame     #fame      http://livfame.com
# 1  /Organization/-Qounter  :Qounter  http://www.qounter.com
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
#
#   state_code      region           city  founded_at companyname  \
# 0         16      Mumbai         Mumbai         NaN        fame
# 1         DE  DE - Other  Delaware City  04-09-2014     qounter
#
#         company_permalink                          funding_round_permalink  \
# 0     /organization/-fame  /funding-round/9a01d05418af9f794eebff7ace91f638
# 1  /ORGANIZATION/-QOUNTER  /funding-round/22dacff496eb7acb2b901dec1dfe5633
#
#   funding_round_type funding_round_code   funded_at  raised_amount_usd
# 0            venture                  B  05-01-2015         10000000.0
# 1            venture                  A  14-10-2014                NaN

# %%
#5. How many observations are present in master_frame?
master_frame.shape
# Out:
# (115200, 17)

# %% [markdown]
# Problem 2: Funding Type Analysis
# #1. Calculate the most representative value of the investment amount for
# each of the four funding types (venture, angel, seed, and private equity) and
# report the answers in the template provided on the previous page

# %%
master_frame.columns
# Out:
# Index(['permalink', 'name', 'homepage_url', 'category_list', 'status',
#        'country_code', 'state_code', 'region', 'city', 'founded_at',
#        'companyname', 'company_permalink', 'funding_round_permalink',
#        'funding_round_type', 'funding_round_code', 'funded_at',
#        'raised_amount_usd'],
#       dtype='object')

# %%
master_frame.groupby('funding_round_type')['raised_amount_usd'].mean()
# Out:
# funding_round_type
# angel                    9.576585e+05
# convertible_note         1.452657e+06
# debt_financing           1.703727e+07
# equity_crowdfunding      5.395575e+05
# grant                    4.292670e+06
# non_equity_assistance    4.112031e+05
# post_ipo_debt            1.687046e+08
# post_ipo_equity          8.218249e+07
# private_equity           7.324408e+07
# product_crowdfunding     1.356929e+06
# secondary_market         7.964963e+07
# seed                     7.197503e+05
# undisclosed              1.918091e+07
# venture                  1.175197e+07
# Name: raised_amount_usd, dtype: float64

# %% [markdown]
# 2. Based on the most representative investment amount calculated above, which
# investment type do you think is the most suitable for Teclov?
# Ans:'angel' investment type is the most suitable type for Teclov

# %%
master_frame['funding_round_type']=='angel'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 115195    False
# 115196    False
# 115197    False
# 115198    False
# 115199    False
# Name: funding_round_type, Length: 115200, dtype: bool

# %%
master_frame[master_frame['funding_round_type']=='angel']
# Out:
#                                permalink                                 name  \
# 32                 /Organization/1000Chi  Beijing 1000CHI Software Technology
# 51                 /Organization/1006-Tv                              1006.tv
# 69      /Organization/10Seconds-Software                   10seconds Software
# 79       /Organization/115-Network-Disks                    115 network disks
# 93                /Organization/121Nexus                             121nexus
# ...                                  ...                                  ...
# 115164               /Organization/Zynga                                Zynga
# 115170             /Organization/Zynstra                              Zynstra
# 115180    /Organization/Zyraz-Technology                     Zyraz Technology
# 115186               /Organization/Zyrra                                Zyrra
# 115190               /Organization/Zzish                                Zzish
#
#                             homepage_url  \
# 32               http://www.1000chi.com/
# 51                   http://www.1006.tv/
# 69      http://www.10secondsSoftware.com
# 79                   http://www.115.com/
# 93               http://www.121nexus.com
# ...                                  ...
# 115164              http://www.zynga.com
# 115170            http://www.zynstra.com
# 115180              http://www.zyraz.com
# 115186              http://www.zyrra.com
# 115190              http://www.zzish.com
#
#                                             category_list     status  \
# 32                                                 Mobile  operating
# 51                                            Games|Media  operating
# 69                  Enterprise Software|Mobility|Software  operating
# 79                                       EdTech|Education  operating
# 93      Health Diagnostics|Medical Devices|Personaliza...  operating
# ...                                                   ...        ...
# 115164  Facebook Applications|Games|Networking|Technology        ipo
# 115170                                           Software  operating
# 115180                                      Biotechnology     closed
# 115186                                         E-Commerce  operating
# 115190  Analytics|Android|Developer APIs|Education|Gam...  operating
#
#        country_code state_code       region                   city  \
# 32              NaN        NaN          NaN                    NaN
# 51              CHN         22      Beijing                Beijing
# 69              AUS          2       Sydney                 Sydney
# 79              NaN        NaN          NaN                    NaN
# 93              USA         RI   Providence             Providence
# ...             ...        ...          ...                    ...
# 115164          USA         CA  SF Bay Area          San Francisco
# 115170          GBR         A4         Bath                   Bath
# 115180          MYS         14  MYS - Other  Damansara New Village
# 115186          USA         MA       Boston              Cambridge
# 115190          GBR         H9       London                 London
#
#         founded_at        companyname                 company_permalink  \
# 32      01-01-2008            1000chi             /organization/1000chi
# 51      01-01-2009             1006tv             /ORGANIZATION/1006-TV
# 69      01-07-2009  10secondssoftware  /ORGANIZATION/10SECONDS-SOFTWARE
# 79             NaN    115networkdisks   /ORGANIZATION/115-NETWORK-DISKS
# 93      07-10-2011           121nexus            /ORGANIZATION/121NEXUS
# ...            ...                ...                               ...
# 115164  01-07-2007              zynga               /ORGANIZATION/ZYNGA
# 115170  30-11-2011            zynstra             /ORGANIZATION/ZYNSTRA
# 115180  01-01-1994    zyraztechnology    /ORGANIZATION/ZYRAZ-TECHNOLOGY
# 115186         NaN              zyrra               /ORGANIZATION/ZYRRA
# 115190  28-01-2014              zzish               /ORGANIZATION/ZZISH
#
#                                 funding_round_permalink funding_round_type  \
# 32      /funding-round/854fae13c5b26b2ea6b32b06c2e5890c              angel
# 51      /funding-round/a3631227d5232aa8c2303f252c4f1f87              angel
# 69      /funding-round/dacf342722793cb7485fbdbd7530461d              angel
# 79      /funding-round/0966b3b472f4b912e167abaf8d06f77d              angel
# 93      /funding-round/9df05fa02b09752fcd0ecbf4e167cbef              angel
# ...                                                 ...                ...
# 115164  /funding-round/d27f10a20b15b4ef3d9961d54eabf6b1              angel
# 115170  /funding-round/dee233b3434185c14b3352034f72d798              angel
# 115180  /funding-round/55f33b179dd6f4516315348c1e8350c6              angel
# 115186  /funding-round/cc8cd96a500332d5b4f4bcbddb306099              angel
# 115190  /funding-round/4c82e18a8e3eab2647719d0fc27ead5f              angel
#
#        funding_round_code   funded_at  raised_amount_usd
# 32                    NaN  01-04-2010         43923865.0
# 51                    NaN  01-01-2011                NaN
# 69                    NaN  01-07-2010           100000.0
# 79                    NaN  01-11-2011                NaN
# 93                    NaN  22-01-2013           500000.0
# ...                   ...         ...                ...
# 115164                NaN  01-01-2007                NaN
# 115170                NaN  18-09-2012          2325000.0
# 115180                NaN  01-01-2008          2007363.0
# 115186                NaN  15-12-2010           875000.0
# 115190                NaN  31-10-2014           400000.0
#
# [6104 rows x 17 columns]

# %%
angel_data = master_frame[master_frame['funding_round_type']=='angel']

# %%
angel_data['raised_amount_usd'].mean()
# Out:
# 957658.4553296365

# %% [markdown]
# PROBLEM PART 2
# Problem 3: Country Analysis

# %% [markdown]
# 1. Teclov wants to see the top nine countries which have received the highest
# total funding (across ALL sectors for the chosen investment type)

# %%
angel_data.columns
# Out:
# Index(['permalink', 'name', 'homepage_url', 'category_list', 'status',
#        'country_code', 'state_code', 'region', 'city', 'founded_at',
#        'companyname', 'company_permalink', 'funding_round_permalink',
#        'funding_round_type', 'funding_round_code', 'funded_at',
#        'raised_amount_usd'],
#       dtype='object')

# %%
angel_data.groupby('country_code')['raised_amount_usd'].mean()
# Out:
# country_code
# ARE    5.262500e+05
# ARG    2.691288e+05
# AUS    1.119190e+06
# AUT    6.464935e+05
# BEL    6.337728e+05
#            ...
# URY    3.000000e+05
# USA    8.898619e+05
# VEN             NaN
# VNM    5.000000e+04
# ZAF    3.728500e+05
# Name: raised_amount_usd, Length: 88, dtype: float64

# %%
angel_data['country_code']=='USA'
# Out:
# 32        False
# 51        False
# 69        False
# 79        False
# 93         True
#           ...
# 115164     True
# 115170    False
# 115180    False
# 115186     True
# 115190    False
# Name: country_code, Length: 6104, dtype: bool

# %%
angel_data[angel_data['country_code']=='USA']
# Out:
#                       permalink        name                  homepage_url  \
# 93       /Organization/121Nexus    121nexus       http://www.121nexus.com
# 125        /Organization/15Five      15Five             http://15five.com
# 126        /Organization/15Five      15Five             http://15five.com
# 130        /Organization/169-St     169 ST.  http://www.junebugreview.com
# 143       /Organization/17Zuoye     17zuoye       http://www.17zuoye.com/
# ...                         ...         ...                           ...
# 115148  /Organization/Zymr-Inc-  Zymr, Inc.           http://www.zymr.com
# 115149  /Organization/Zymr-Inc-  Zymr, Inc.           http://www.zymr.com
# 115150  /Organization/Zymr-Inc-  Zymr, Inc.           http://www.zymr.com
# 115164      /Organization/Zynga       Zynga          http://www.zynga.com
# 115186      /Organization/Zyrra       Zyrra          http://www.zyrra.com
#
#                                             category_list     status  \
# 93      Health Diagnostics|Medical Devices|Personaliza...  operating
# 125                                              Software  operating
# 126                                              Software  operating
# 130                                   Entertainment|Games     closed
# 143                           Education|Language Learning  operating
# ...                                                   ...        ...
# 115148  Android|Apps|Cloud Computing|Cloud Infrastruct...  operating
# 115149  Android|Apps|Cloud Computing|Cloud Infrastruct...  operating
# 115150  Android|Apps|Cloud Computing|Cloud Infrastruct...  operating
# 115164  Facebook Applications|Games|Networking|Technology        ipo
# 115186                                         E-Commerce  operating
#
#        country_code state_code       region           city  founded_at  \
# 93              USA         RI   Providence     Providence  07-10-2011
# 125             USA         CA  SF Bay Area  San Francisco  01-05-2011
# 126             USA         CA  SF Bay Area  San Francisco  01-05-2011
# 130             USA         FL      Orlando      Lake Mary  15-05-2009
# 143             USA         VA   VA - Other       Shanghai  01-01-2007
# ...             ...        ...          ...            ...         ...
# 115148          USA         CA  SF Bay Area    Santa Clara         NaN
# 115149          USA         CA  SF Bay Area    Santa Clara         NaN
# 115150          USA         CA  SF Bay Area    Santa Clara         NaN
# 115164          USA         CA  SF Bay Area  San Francisco  01-07-2007
# 115186          USA         MA       Boston      Cambridge         NaN
#
#        companyname        company_permalink  \
# 93        121nexus   /ORGANIZATION/121NEXUS
# 125         15five     /ORGANIZATION/15FIVE
# 126         15five     /organization/15five
# 130          169st     /organization/169-st
# 143        17zuoye    /ORGANIZATION/17ZUOYE
# ...            ...                      ...
# 115148     zymrinc  /ORGANIZATION/ZYMR-INC-
# 115149     zymrinc  /organization/zymr-inc-
# 115150     zymrinc  /ORGANIZATION/ZYMR-INC-
# 115164       zynga      /ORGANIZATION/ZYNGA
# 115186       zyrra      /ORGANIZATION/ZYRRA
#
#                                 funding_round_permalink funding_round_type  \
# 93      /funding-round/9df05fa02b09752fcd0ecbf4e167cbef              angel
# 125     /funding-round/6c390df9112bb5ee560d419450536bd7              angel
# 126     /funding-round/e7ce4181f0de392140ff584986340a54              angel
# 130     /funding-round/83b14cdf635963a5abc50cdafd9b462d              angel
# 143     /funding-round/afb6af473d17ff47d29e6e680c959379              angel
# ...                                                 ...                ...
# 115148  /funding-round/4d834ddb3c11728e1d0089efb998ec5b              angel
# 115149  /funding-round/651a78538c9b95afed28a47fb9244442              angel
# 115150  /funding-round/9048d1a80edeae803ed1790c9f473eec              angel
# 115164  /funding-round/d27f10a20b15b4ef3d9961d54eabf6b1              angel
# 115186  /funding-round/cc8cd96a500332d5b4f4bcbddb306099              angel
#
#        funding_round_code   funded_at  raised_amount_usd
# 93                    NaN  22-01-2013           500000.0
# 125                   NaN  15-01-2013          1000000.0
# 126                   NaN  01-01-2012           200000.0
# 130                   NaN  01-06-2009            50000.0
# 143                   NaN  01-01-2011                NaN
# ...                   ...         ...                ...
# 115148                NaN  01-01-2013                NaN
# 115149                NaN  01-01-2014                NaN
# 115150                NaN  12-12-2012                NaN
# 115164                NaN  01-01-2007                NaN
# 115186                NaN  15-12-2010           875000.0
#
# [2762 rows x 17 columns]
